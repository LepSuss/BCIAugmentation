# %%
from scipy.io import loadmat
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pymatreader import read_mat
import tensorflow as tf
from tensorflow import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import eeg_funcs

# %%
filepath = glob('data/train/*.mat')
d_array, d_labels = eeg_funcs.get_comp2_array(filepath, True, True)
print(d_array.shape)
# Out:
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=29568
#     Range : 0 ... 29567 =      0.000 ...   123.196 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 541 events found
# Event IDs: [1 2]
# Not setting metadata
# 541 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 541 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=29568
#     Range : 0 ... 29567 =      0.000 ...   123.196 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 541 events found
# Event IDs: [1 2]
# Not setting metadata
# 541 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 541 events and 160 original time points ...
# 0 bad epochs dropped
# (12600, 160, 8)

# %%
print(d_array.shape, d_labels.shape)
print(d_labels[2875])
plt.plot(d_array[2875,:,5])
# Out:
# (12600, 160, 8) (12600,)
# 0

# %%
#t_array = np.expand_dims(d_array, axis=3)
#data_array = t_array
#data_array = tf.convert_to_tensor(data_array, dtype=tf.float32)
data_array = tf.convert_to_tensor(d_array, dtype=tf.float32)

# %%
BUFFER_SIZE = 30000
BATCH_SIZE = 64
train_dataset = tf.data.Dataset.from_tensor_slices(data_array).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %%
discriminator = keras.Sequential(
    [
        keras.Input(shape=data_array.shape[1:]),
        layers.Conv1D(64, kernel_size=4, strides=2, padding="same"),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.2),
        layers.Conv1D(128, kernel_size=4, strides=2, padding="same"),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(1, activation="sigmoid"),
    ],
    name="discriminator",
)
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 80, 64)            2112
#
#  batch_normalization_9 (Batc  (None, 80, 64)           256
#  hNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 80, 64)            0
#
#  dropout_2 (Dropout)         (None, 80, 64)            0
#
#  conv1d_3 (Conv1D)           (None, 40, 128)           32896
#
#  batch_normalization_10 (Bat  (None, 40, 128)          512
#  chNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 40, 128)           0
#
#  dropout_3 (Dropout)         (None, 40, 128)           0
#
#  flatten_1 (Flatten)         (None, 5120)              0
#
#  dense_4 (Dense)             (None, 1)                 5121
#
# =================================================================
# Total params: 40,897
# Trainable params: 40,513
# Non-trainable params: 384
# _________________________________________________________________

# %%
latent_dim = 128

generator = keras.Sequential(
    [
        keras.Input(shape=(latent_dim,)),
        layers.Dense(10*256, use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),
        layers.Reshape((10, 256)),
        layers.Conv1DTranspose(128, 4, strides=2, padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv1DTranspose(64, 4, strides=4, padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv1DTranspose(8, 4, strides=2, padding='same', use_bias=False, activation='tanh'),
    ],
    name="generator",
)
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_4 (Reshape)         (None, 10, 16)            0
#
#  conv1d_transpose_12 (Conv1D  (None, 20, 128)          8192
#  Transpose)
#
#  batch_normalization_13 (Bat  (None, 20, 128)          512
#  chNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 20, 128)           0
#
#  conv1d_transpose_13 (Conv1D  (None, 80, 64)           32768
#  Transpose)
#
#  batch_normalization_14 (Bat  (None, 80, 64)           256
#  chNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 80, 64)            0
#
#  conv1d_transpose_14 (Conv1D  (None, 160, 8)           2048
#  Transpose)
#
# =================================================================
# Total params: 43,776
# Trainable params: 43,392
# Non-trainable params: 384
# _________________________________________________________________

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn
        self.d_loss_metric = keras.metrics.Mean(name="d_loss")
        self.g_loss_metric = keras.metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, real_images):
        # Sample random points in the latent space
        batch_size = tf.shape(real_images)[0]
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        # Decode them to fake images
        generated_images = self.generator(random_latent_vectors)

        # Combine them with real images
        combined_images = tf.concat([generated_images, real_images], axis=0)

        # Assemble labels discriminating real from fake images
        labels = tf.concat(
            [tf.ones((batch_size, 1)), tf.zeros((batch_size, 1))], axis=0
        )
        # Add random noise to the labels - important trick!
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # Train the discriminator
        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_images)
            d_loss = self.loss_fn(labels, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(zip(grads, self.discriminator.trainable_weights))

        # Sample random points in the latent space
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        # Assemble labels that say "all real images"
        misleading_labels = tf.zeros((batch_size, 1))

        # Train the generator (note that we should *not* update the weights
        # of the discriminator)!
        with tf.GradientTape() as tape:
            predictions = self.discriminator(self.generator(random_latent_vectors))
            g_loss = self.loss_fn(misleading_labels, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Update metrics
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)
        return {
            "d_loss": self.d_loss_metric.result(),
            "g_loss": self.g_loss_metric.result(),
        }

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=1, latent_dim=100):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator(random_latent_vectors)
        generated_images.numpy()
        for i in range(self.num_img):
            img = generated_images[i]
            img = img[:,3]
            plt.plot(img)
            plt.savefig("testimages/generated_img_%03d_%d.png" % (epoch, i))
            plt.clf()
            ##img = keras.preprocessing.image.array_to_img(generated_images[i])
            ##img.save("generated_img_%03d_%d.png" % (epoch, i))

# %%
checkpoint_filepath = 'checkpointTMP/checkpoint.{epoch:02d}'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='g_loss',
    mode='min',
    save_best_only=True)

# %%
epochs = 3500  # In practice, use ~100 epochs

gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.00001, beta_1=0.5),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.00001, beta_1=0.5),
    loss_fn=keras.losses.BinaryCrossentropy(),
)

gan.fit(
    train_dataset, epochs=epochs, callbacks=[GANMonitor(num_img=1, latent_dim=latent_dim), model_checkpoint_callback]
)
# Out:
# Epoch 1/3500
# 197/197 [==============================] - 6s 9ms/step - d_loss: 0.6795 - g_loss: 0.7184
# Epoch 2/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6554 - g_loss: 0.7615
# Epoch 3/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6307 - g_loss: 0.8049
# Epoch 4/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5994 - g_loss: 0.8574
# Epoch 5/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5723 - g_loss: 0.8925
# Epoch 6/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5551 - g_loss: 0.9081
# Epoch 7/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5476 - g_loss: 0.9179
# Epoch 8/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5479 - g_loss: 0.9190
# Epoch 9/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5581 - g_loss: 0.9051
# Epoch 10/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5740 - g_loss: 0.8837
# Epoch 11/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5882 - g_loss: 0.8657
# Epoch 12/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5983 - g_loss: 0.8523
# Epoch 13/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6053 - g_loss: 0.8443
# Epoch 14/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6101 - g_loss: 0.8384
# Epoch 15/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6139 - g_loss: 0.8333
# Epoch 16/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6171 - g_loss: 0.8296
# Epoch 17/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6203 - g_loss: 0.8258
# Epoch 18/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6235 - g_loss: 0.8219
# Epoch 19/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6270 - g_loss: 0.8177
# Epoch 20/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6306 - g_loss: 0.8130
# Epoch 21/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6344 - g_loss: 0.8088
# Epoch 22/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6382 - g_loss: 0.8040
# Epoch 23/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6424 - g_loss: 0.7992
# Epoch 24/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6463 - g_loss: 0.7947
# Epoch 25/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6503 - g_loss: 0.7903
# Epoch 26/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6541 - g_loss: 0.7859
# Epoch 27/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6578 - g_loss: 0.7818
# Epoch 28/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6613 - g_loss: 0.7776
# Epoch 29/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6644 - g_loss: 0.7743
# Epoch 30/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6673 - g_loss: 0.7711
# Epoch 31/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6699 - g_loss: 0.7683
# Epoch 32/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6722 - g_loss: 0.7658
# Epoch 33/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6742 - g_loss: 0.7636
# Epoch 34/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6760 - g_loss: 0.7619
# Epoch 35/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6777 - g_loss: 0.7604
# Epoch 36/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6791 - g_loss: 0.7582
# Epoch 37/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6804 - g_loss: 0.7572
# Epoch 38/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6816 - g_loss: 0.7566
# Epoch 39/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6827 - g_loss: 0.7551
# Epoch 40/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6837 - g_loss: 0.7539
# Epoch 41/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6846 - g_loss: 0.7527
# Epoch 42/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6854 - g_loss: 0.7522
# Epoch 43/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6862 - g_loss: 0.7516
# Epoch 44/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6869 - g_loss: 0.7516
# Epoch 45/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6875 - g_loss: 0.7496
# Epoch 46/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6881 - g_loss: 0.7490
# Epoch 47/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6886 - g_loss: 0.7486
# Epoch 48/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6890 - g_loss: 0.7483
# Epoch 49/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6897 - g_loss: 0.7501
# Epoch 50/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6901 - g_loss: 0.7484
# Epoch 51/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6900 - g_loss: 0.7463
# Epoch 52/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6902 - g_loss: 0.7464
# Epoch 53/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6905 - g_loss: 0.7462
# Epoch 54/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6907 - g_loss: 0.7464
# Epoch 55/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6909 - g_loss: 0.7463
# Epoch 56/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6911 - g_loss: 0.7460
# Epoch 57/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6912 - g_loss: 0.7457
# Epoch 58/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6913 - g_loss: 0.7453
# Epoch 59/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6913 - g_loss: 0.7456
# Epoch 60/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6915 - g_loss: 0.7457
# Epoch 61/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7468
# Epoch 62/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7469
# Epoch 63/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7457
# Epoch 64/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7451
# Epoch 65/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7449
# Epoch 66/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7450
# Epoch 67/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7450
# Epoch 68/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7452
# Epoch 69/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7450
# Epoch 70/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7452
# Epoch 71/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7449
# Epoch 72/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7452
# Epoch 73/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6925 - g_loss: 0.7469
# Epoch 74/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6925 - g_loss: 0.7461
# Epoch 75/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6925 - g_loss: 0.7452
# Epoch 76/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7449
# Epoch 77/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7448
# Epoch 78/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7450
# Epoch 79/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7447
# Epoch 80/3500
# 197/197 [==============================] - 2s 10ms/step - d_loss: 0.6921 - g_loss: 0.7452
# Epoch 81/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7451
# Epoch 82/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7448
# Epoch 83/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7447
# Epoch 84/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7449
# Epoch 85/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6924 - g_loss: 0.7452
# Epoch 86/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6924 - g_loss: 0.7449
# Epoch 87/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6924 - g_loss: 0.7448
# Epoch 88/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6924 - g_loss: 0.7453
# Epoch 89/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7450
# Epoch 90/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7448
# Epoch 91/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7450
# Epoch 92/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7449
# Epoch 93/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6924 - g_loss: 0.7449
# Epoch 94/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6924 - g_loss: 0.7449
# Epoch 95/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6924 - g_loss: 0.7448
# Epoch 96/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7444
# Epoch 97/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6924 - g_loss: 0.7454
# Epoch 98/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7447
# Epoch 99/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7446
# Epoch 100/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7447
# Epoch 101/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7444
# Epoch 102/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7448
# Epoch 103/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7444
# Epoch 104/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7446
# Epoch 105/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7447
# Epoch 106/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7449
# Epoch 107/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7454
# Epoch 108/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7451
# Epoch 109/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7450
# Epoch 110/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7455
# Epoch 111/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7451
# Epoch 112/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7449
# Epoch 113/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6923 - g_loss: 0.7452
# Epoch 114/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7448
# Epoch 115/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7444
# Epoch 116/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7449
# Epoch 117/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7450
# Epoch 118/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7445
# Epoch 119/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7447
# Epoch 120/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7449
# Epoch 121/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7446
# Epoch 122/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7450
# Epoch 123/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7449
# Epoch 124/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6922 - g_loss: 0.7449
# Epoch 125/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7448
# Epoch 126/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7447
# Epoch 127/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7445
# Epoch 128/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7448
# Epoch 129/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7442
# Epoch 130/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7446
# Epoch 131/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7445
# Epoch 132/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7444
# Epoch 133/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7446
# Epoch 134/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7450
# Epoch 135/3500
# 197/197 [==============================] - 2s 10ms/step - d_loss: 0.6921 - g_loss: 0.7447
# Epoch 136/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7451
# Epoch 137/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7449
# Epoch 138/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7446
# Epoch 139/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7448
# Epoch 140/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7449
# Epoch 141/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7447
# Epoch 142/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7451
# Epoch 143/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7451
# Epoch 144/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7451
# Epoch 145/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7451
# Epoch 146/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6921 - g_loss: 0.7450
# Epoch 147/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7449
# Epoch 148/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7446
# Epoch 149/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7445
# Epoch 150/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7449
# Epoch 151/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7447
# Epoch 152/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7451
# Epoch 153/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7449
# Epoch 154/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6920 - g_loss: 0.7449
# Epoch 155/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7448
# Epoch 156/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7453
# Epoch 157/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7449
# Epoch 158/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7451
# Epoch 159/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6917 - g_loss: 0.7450
# Epoch 160/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6919 - g_loss: 0.7451
# Epoch 161/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6916 - g_loss: 0.7454
# Epoch 162/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7447
# Epoch 163/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6916 - g_loss: 0.7454
# Epoch 164/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7451
# Epoch 165/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6916 - g_loss: 0.7451
# Epoch 166/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6917 - g_loss: 0.7450
# Epoch 167/3500
# 197/197 [==============================] - 2s 10ms/step - d_loss: 0.6919 - g_loss: 0.7451
# Epoch 168/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6914 - g_loss: 0.7453
# Epoch 169/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6917 - g_loss: 0.7455
# Epoch 170/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6918 - g_loss: 0.7450
# Epoch 171/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6915 - g_loss: 0.7453
# Epoch 172/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6916 - g_loss: 0.7449
# Epoch 173/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6917 - g_loss: 0.7455
# Epoch 174/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6915 - g_loss: 0.7456
# Epoch 175/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6915 - g_loss: 0.7450
# Epoch 176/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6916 - g_loss: 0.7450
# Epoch 177/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6915 - g_loss: 0.7453
# Epoch 178/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6916 - g_loss: 0.7452
# Epoch 179/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6914 - g_loss: 0.7452
# Epoch 180/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6914 - g_loss: 0.7456
# Epoch 181/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6914 - g_loss: 0.7457
# Epoch 182/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6915 - g_loss: 0.7451
# Epoch 183/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6914 - g_loss: 0.7454
# Epoch 184/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6914 - g_loss: 0.7453
# Epoch 185/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6913 - g_loss: 0.7452
# Epoch 186/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6913 - g_loss: 0.7454
# Epoch 187/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6912 - g_loss: 0.7454
# Epoch 188/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6912 - g_loss: 0.7454
# Epoch 189/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6912 - g_loss: 0.7458
# Epoch 190/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6912 - g_loss: 0.7453
# Epoch 191/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6912 - g_loss: 0.7456
# Epoch 192/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6911 - g_loss: 0.7459
# Epoch 193/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6910 - g_loss: 0.7456
# Epoch 194/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6909 - g_loss: 0.7460
# Epoch 195/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6910 - g_loss: 0.7457
# Epoch 196/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6909 - g_loss: 0.7460
# Epoch 197/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6908 - g_loss: 0.7459
# Epoch 198/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6908 - g_loss: 0.7458
# Epoch 199/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6908 - g_loss: 0.7461
# Epoch 200/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6906 - g_loss: 0.7462
# Epoch 201/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6906 - g_loss: 0.7459
# Epoch 202/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6905 - g_loss: 0.7460
# Epoch 203/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6905 - g_loss: 0.7465
# Epoch 204/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6905 - g_loss: 0.7462
# Epoch 205/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6904 - g_loss: 0.7463
# Epoch 206/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6903 - g_loss: 0.7465
# Epoch 207/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6902 - g_loss: 0.7464
# Epoch 208/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6902 - g_loss: 0.7461
# Epoch 209/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6901 - g_loss: 0.7468
# Epoch 210/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6900 - g_loss: 0.7474
# Epoch 211/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6899 - g_loss: 0.7470
# Epoch 212/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6897 - g_loss: 0.7476
# Epoch 213/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6897 - g_loss: 0.7471
# Epoch 214/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6895 - g_loss: 0.7471
# Epoch 215/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6893 - g_loss: 0.7473
# Epoch 216/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6891 - g_loss: 0.7475
# Epoch 217/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6890 - g_loss: 0.7479
# Epoch 218/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6888 - g_loss: 0.7479
# Epoch 219/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6886 - g_loss: 0.7480
# Epoch 220/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6885 - g_loss: 0.7483
# Epoch 221/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6884 - g_loss: 0.7485
# Epoch 222/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6881 - g_loss: 0.7488
# Epoch 223/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6879 - g_loss: 0.7490
# Epoch 224/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6877 - g_loss: 0.7493
# Epoch 225/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6875 - g_loss: 0.7495
# Epoch 226/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6871 - g_loss: 0.7496
# Epoch 227/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6869 - g_loss: 0.7503
# Epoch 228/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6866 - g_loss: 0.7507
# Epoch 229/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6864 - g_loss: 0.7509
# Epoch 230/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6861 - g_loss: 0.7509
# Epoch 231/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6857 - g_loss: 0.7516
# Epoch 232/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6853 - g_loss: 0.7524
# Epoch 233/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6849 - g_loss: 0.7524
# Epoch 234/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6846 - g_loss: 0.7529
# Epoch 235/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6840 - g_loss: 0.7534
# Epoch 236/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6835 - g_loss: 0.7546
# Epoch 237/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6831 - g_loss: 0.7541
# Epoch 238/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6827 - g_loss: 0.7545
# Epoch 239/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6821 - g_loss: 0.7555
# Epoch 240/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6815 - g_loss: 0.7561
# Epoch 241/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6811 - g_loss: 0.7568
# Epoch 242/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6804 - g_loss: 0.7576
# Epoch 243/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6799 - g_loss: 0.7589
# Epoch 244/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6791 - g_loss: 0.7592
# Epoch 245/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6781 - g_loss: 0.7605
# Epoch 246/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6775 - g_loss: 0.7614
# Epoch 247/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6766 - g_loss: 0.7619
# Epoch 248/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6758 - g_loss: 0.7632
# Epoch 249/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6750 - g_loss: 0.7645
# Epoch 250/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6742 - g_loss: 0.7649
# Epoch 251/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6731 - g_loss: 0.7673
# Epoch 252/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6724 - g_loss: 0.7684
# Epoch 253/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6712 - g_loss: 0.7687
# Epoch 254/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6703 - g_loss: 0.7705
# Epoch 255/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6694 - g_loss: 0.7718
# Epoch 256/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6683 - g_loss: 0.7724
# Epoch 257/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6678 - g_loss: 0.7737
# Epoch 258/3500
# 197/197 [==============================] - 2s 10ms/step - d_loss: 0.6668 - g_loss: 0.7756
# Epoch 259/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6657 - g_loss: 0.7764
# Epoch 260/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6648 - g_loss: 0.7776
# Epoch 261/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6636 - g_loss: 0.7786
# Epoch 262/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6628 - g_loss: 0.7801
# Epoch 263/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6617 - g_loss: 0.7818
# Epoch 264/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6605 - g_loss: 0.7832
# Epoch 265/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6595 - g_loss: 0.7844
# Epoch 266/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6588 - g_loss: 0.7857
# Epoch 267/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6579 - g_loss: 0.7874
# Epoch 268/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6567 - g_loss: 0.7883
# Epoch 269/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6558 - g_loss: 0.7899
# Epoch 270/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6545 - g_loss: 0.7907
# Epoch 271/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6536 - g_loss: 0.7933
# Epoch 272/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6525 - g_loss: 0.7936
# Epoch 273/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6522 - g_loss: 0.7971
# Epoch 274/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6506 - g_loss: 0.7978
# Epoch 275/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6497 - g_loss: 0.7985
# Epoch 276/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6487 - g_loss: 0.8016
# Epoch 277/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6476 - g_loss: 0.8013
# Epoch 278/3500
# 197/197 [==============================] - 2s 10ms/step - d_loss: 0.6469 - g_loss: 0.8032
# Epoch 279/3500
# 197/197 [==============================] - 2s 10ms/step - d_loss: 0.6451 - g_loss: 0.8075
# Epoch 280/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6452 - g_loss: 0.8039
# Epoch 281/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6434 - g_loss: 0.8091
# Epoch 282/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6425 - g_loss: 0.8091
# Epoch 283/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6418 - g_loss: 0.8134
# Epoch 284/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6398 - g_loss: 0.8162
# Epoch 285/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6396 - g_loss: 0.8137
# Epoch 286/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6381 - g_loss: 0.8171
# Epoch 287/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6371 - g_loss: 0.8178
# Epoch 288/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6362 - g_loss: 0.8219
# Epoch 289/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6342 - g_loss: 0.8241
# Epoch 290/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6340 - g_loss: 0.8230
# Epoch 291/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6323 - g_loss: 0.8280
# Epoch 292/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6306 - g_loss: 0.8306
# Epoch 293/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6310 - g_loss: 0.8310
# Epoch 294/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6289 - g_loss: 0.8296
# Epoch 295/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6281 - g_loss: 0.8356
# Epoch 296/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6278 - g_loss: 0.8372
# Epoch 297/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6255 - g_loss: 0.8391
# Epoch 298/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6253 - g_loss: 0.8403
# Epoch 299/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6231 - g_loss: 0.8419
# Epoch 300/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6227 - g_loss: 0.8454
# Epoch 301/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6220 - g_loss: 0.8450
# Epoch 302/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6200 - g_loss: 0.8506
# Epoch 303/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6200 - g_loss: 0.8486
# Epoch 304/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6186 - g_loss: 0.8549
# Epoch 305/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6181 - g_loss: 0.8548
# Epoch 306/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6166 - g_loss: 0.8571
# Epoch 307/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6156 - g_loss: 0.8592
# Epoch 308/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6146 - g_loss: 0.8602
# Epoch 309/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6134 - g_loss: 0.8647
# Epoch 310/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6124 - g_loss: 0.8626
# Epoch 311/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6119 - g_loss: 0.8684
# Epoch 312/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6104 - g_loss: 0.8723
# Epoch 313/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6102 - g_loss: 0.8687
# Epoch 314/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6087 - g_loss: 0.8758
# Epoch 315/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6082 - g_loss: 0.8728
# Epoch 316/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6065 - g_loss: 0.8802
# Epoch 317/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6058 - g_loss: 0.8768
# Epoch 318/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6047 - g_loss: 0.8852
# Epoch 319/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6037 - g_loss: 0.8828
# Epoch 320/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6030 - g_loss: 0.8871
# Epoch 321/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6020 - g_loss: 0.8906
# Epoch 322/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6017 - g_loss: 0.8876
# Epoch 323/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5999 - g_loss: 0.8917
# Epoch 324/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5991 - g_loss: 0.8964
# Epoch 325/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5994 - g_loss: 0.8937
# Epoch 326/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5978 - g_loss: 0.8969
# Epoch 327/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5962 - g_loss: 0.9029
# Epoch 328/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5947 - g_loss: 0.9016
# Epoch 329/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5949 - g_loss: 0.9065
# Epoch 330/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5937 - g_loss: 0.9063
# Epoch 331/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5932 - g_loss: 0.9073
# Epoch 332/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5924 - g_loss: 0.9123
# Epoch 333/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5915 - g_loss: 0.9134
# Epoch 334/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5908 - g_loss: 0.9155
# Epoch 335/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5885 - g_loss: 0.9192
# Epoch 336/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5891 - g_loss: 0.9153
# Epoch 337/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5880 - g_loss: 0.9239
# Epoch 338/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5874 - g_loss: 0.9242
# Epoch 339/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5860 - g_loss: 0.9273
# Epoch 340/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5852 - g_loss: 0.9292
# Epoch 341/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5850 - g_loss: 0.9280
# Epoch 342/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5827 - g_loss: 0.9331
# Epoch 343/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5822 - g_loss: 0.9352
# Epoch 344/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5814 - g_loss: 0.9351
# Epoch 345/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5808 - g_loss: 0.9382
# Epoch 346/3500
# 197/197 [==============================] - 2s 10ms/step - d_loss: 0.5809 - g_loss: 0.9417
# Epoch 347/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5785 - g_loss: 0.9470
# Epoch 348/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5785 - g_loss: 0.9406
# Epoch 349/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5772 - g_loss: 0.9509
# Epoch 350/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5778 - g_loss: 0.9418
# Epoch 351/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5758 - g_loss: 0.9533
# Epoch 352/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5754 - g_loss: 0.9530
# Epoch 353/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5753 - g_loss: 0.9541
# Epoch 354/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5727 - g_loss: 0.9593
# Epoch 355/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5743 - g_loss: 0.9606
# Epoch 356/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5729 - g_loss: 0.9596
# Epoch 357/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5709 - g_loss: 0.9689
# Epoch 358/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5707 - g_loss: 0.9634
# Epoch 359/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5695 - g_loss: 0.9698
# Epoch 360/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5695 - g_loss: 0.9656
# Epoch 361/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5677 - g_loss: 0.9800
# Epoch 362/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5680 - g_loss: 0.9718
# Epoch 363/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5668 - g_loss: 0.9736
# Epoch 364/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5666 - g_loss: 0.9778
# Epoch 365/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5665 - g_loss: 0.9793
# Epoch 366/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5651 - g_loss: 0.9859
# Epoch 367/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5636 - g_loss: 0.9833
# Epoch 368/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5635 - g_loss: 0.9857
# Epoch 369/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5626 - g_loss: 0.9881
# Epoch 370/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5613 - g_loss: 0.9956
# Epoch 371/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5601 - g_loss: 0.9897
# Epoch 372/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5602 - g_loss: 0.9908
# Epoch 373/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5596 - g_loss: 1.0022
# Epoch 374/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5594 - g_loss: 0.9930
# Epoch 375/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5583 - g_loss: 1.0000
# Epoch 376/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5583 - g_loss: 1.0015
# Epoch 377/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5567 - g_loss: 1.0058
# Epoch 378/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5562 - g_loss: 1.0029
# Epoch 379/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5548 - g_loss: 1.0077
# Epoch 380/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5532 - g_loss: 1.0118
# Epoch 381/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5539 - g_loss: 1.0045
# Epoch 382/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5532 - g_loss: 1.0149
# Epoch 383/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5527 - g_loss: 1.0178
# Epoch 384/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5511 - g_loss: 1.0142
# Epoch 385/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5511 - g_loss: 1.0207
# Epoch 386/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5510 - g_loss: 1.0185
# Epoch 387/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5499 - g_loss: 1.0276
# Epoch 388/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5490 - g_loss: 1.0246
# Epoch 389/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5479 - g_loss: 1.0251
# Epoch 390/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5481 - g_loss: 1.0323
# Epoch 391/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5466 - g_loss: 1.0294
# Epoch 392/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5470 - g_loss: 1.0341
# Epoch 393/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5465 - g_loss: 1.0356
# Epoch 394/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5450 - g_loss: 1.0292
# Epoch 395/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5449 - g_loss: 1.0402
# Epoch 396/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5435 - g_loss: 1.0388
# Epoch 397/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5437 - g_loss: 1.0445
# Epoch 398/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5422 - g_loss: 1.0404
# Epoch 399/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5420 - g_loss: 1.0472
# Epoch 400/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5399 - g_loss: 1.0469
# Epoch 401/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5404 - g_loss: 1.0434
# Epoch 402/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5405 - g_loss: 1.0504
# Epoch 403/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5400 - g_loss: 1.0570
# Epoch 404/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5383 - g_loss: 1.0534
# Epoch 405/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5375 - g_loss: 1.0507
# Epoch 406/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5378 - g_loss: 1.0523
# Epoch 407/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5375 - g_loss: 1.0646
# Epoch 408/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5359 - g_loss: 1.0581
# Epoch 409/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5358 - g_loss: 1.0608
# Epoch 410/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5351 - g_loss: 1.0698
# Epoch 411/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5347 - g_loss: 1.0595
# Epoch 412/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5341 - g_loss: 1.0698
# Epoch 413/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5341 - g_loss: 1.0680
# Epoch 414/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5330 - g_loss: 1.0705
# Epoch 415/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5333 - g_loss: 1.0693
# Epoch 416/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5331 - g_loss: 1.0706
# Epoch 417/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5316 - g_loss: 1.0753
# Epoch 418/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5313 - g_loss: 1.0789
# Epoch 419/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5299 - g_loss: 1.0783
# Epoch 420/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5293 - g_loss: 1.0693
# Epoch 421/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5302 - g_loss: 1.0876
# Epoch 422/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5293 - g_loss: 1.0814
# Epoch 423/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5289 - g_loss: 1.0803
# Epoch 424/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5286 - g_loss: 1.0856
# Epoch 425/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5270 - g_loss: 1.0909
# Epoch 426/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5274 - g_loss: 1.0893
# Epoch 427/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5259 - g_loss: 1.0911
# Epoch 428/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5244 - g_loss: 1.0915
# Epoch 429/3500
# 197/197 [==============================] - 2s 10ms/step - d_loss: 0.5251 - g_loss: 1.0954
# Epoch 430/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5249 - g_loss: 1.0979
# Epoch 431/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5239 - g_loss: 1.0873
# Epoch 432/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5247 - g_loss: 1.0877
# Epoch 433/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5247 - g_loss: 1.1018
# Epoch 434/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5233 - g_loss: 1.1069
# Epoch 435/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5220 - g_loss: 1.0991
# Epoch 436/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5222 - g_loss: 1.1037
# Epoch 437/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5212 - g_loss: 1.1058
# Epoch 438/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5215 - g_loss: 1.1110
# Epoch 439/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5205 - g_loss: 1.1084
# Epoch 440/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5199 - g_loss: 1.1090
# Epoch 441/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5204 - g_loss: 1.1046
# Epoch 442/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5189 - g_loss: 1.1094
# Epoch 443/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5194 - g_loss: 1.1188
# Epoch 444/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5181 - g_loss: 1.1207
# Epoch 445/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5179 - g_loss: 1.1142
# Epoch 446/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5174 - g_loss: 1.1210
# Epoch 447/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5174 - g_loss: 1.1262
# Epoch 448/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5160 - g_loss: 1.1223
# Epoch 449/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5165 - g_loss: 1.1211
# Epoch 450/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5149 - g_loss: 1.1231
# Epoch 451/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5159 - g_loss: 1.1279
# Epoch 452/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5143 - g_loss: 1.1263
# Epoch 453/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5147 - g_loss: 1.1186
# Epoch 454/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5145 - g_loss: 1.1241
# Epoch 455/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5136 - g_loss: 1.1390
# Epoch 456/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5123 - g_loss: 1.1334
# Epoch 457/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5127 - g_loss: 1.1419
# Epoch 458/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5119 - g_loss: 1.1381
# Epoch 459/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5125 - g_loss: 1.1281
# Epoch 460/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5118 - g_loss: 1.1330
# Epoch 461/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5113 - g_loss: 1.1421
# Epoch 462/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5109 - g_loss: 1.1454
# Epoch 463/3500
# ...
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3963 - g_loss: 1.5339
# Epoch 1085/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4120 - g_loss: 1.4572
# Epoch 1086/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4010 - g_loss: 1.5266
# Epoch 1087/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4032 - g_loss: 1.5183
# Epoch 1088/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4039 - g_loss: 1.5194
# Epoch 1089/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4036 - g_loss: 1.5212
# Epoch 1090/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4033 - g_loss: 1.5294
# Epoch 1091/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4033 - g_loss: 1.5325
# Epoch 1092/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4020 - g_loss: 1.5259
# Epoch 1093/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4031 - g_loss: 1.5177
# Epoch 1094/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4032 - g_loss: 1.5278
# Epoch 1095/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4009 - g_loss: 1.5390
# Epoch 1096/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4031 - g_loss: 1.5172
# Epoch 1097/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4025 - g_loss: 1.5286
# Epoch 1098/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4000 - g_loss: 1.5383
# Epoch 1099/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4029 - g_loss: 1.5396
# Epoch 1100/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3991 - g_loss: 1.5390
# Epoch 1101/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3990 - g_loss: 1.5305
# Epoch 1102/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4033 - g_loss: 1.4851
# Epoch 1103/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4011 - g_loss: 1.5316
# Epoch 1104/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3989 - g_loss: 1.5401
# Epoch 1105/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3985 - g_loss: 1.5403
# Epoch 1106/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4041 - g_loss: 1.4959
# Epoch 1107/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4006 - g_loss: 1.5358
# Epoch 1108/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3994 - g_loss: 1.5371
# Epoch 1109/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3995 - g_loss: 1.5449
# Epoch 1110/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4004 - g_loss: 1.5328
# Epoch 1111/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3973 - g_loss: 1.5569
# Epoch 1112/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3986 - g_loss: 1.5351
# Epoch 1113/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4023 - g_loss: 1.5183
# Epoch 1114/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3991 - g_loss: 1.5263
# Epoch 1115/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3985 - g_loss: 1.5479
# Epoch 1116/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3961 - g_loss: 1.5583
# Epoch 1117/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3952 - g_loss: 1.5408
# Epoch 1118/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4039 - g_loss: 1.5025
# Epoch 1119/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3984 - g_loss: 1.5458
# Epoch 1120/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3968 - g_loss: 1.5437
# Epoch 1121/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3970 - g_loss: 1.5345
# Epoch 1122/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3987 - g_loss: 1.5445
# Epoch 1123/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3960 - g_loss: 1.5537
# Epoch 1124/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3950 - g_loss: 1.5454
# Epoch 1125/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3986 - g_loss: 1.5220
# Epoch 1126/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3986 - g_loss: 1.5505
# Epoch 1127/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3957 - g_loss: 1.5532
# Epoch 1128/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3961 - g_loss: 1.5483
# Epoch 1129/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3979 - g_loss: 1.5444
# Epoch 1130/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3957 - g_loss: 1.5624
# Epoch 1131/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3943 - g_loss: 1.5381
# Epoch 1132/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3958 - g_loss: 1.5176
# Epoch 1133/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3990 - g_loss: 1.5577
# Epoch 1134/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3944 - g_loss: 1.5626
# Epoch 1135/3500
# 197/197 [==============================] - 2s 10ms/step - d_loss: 0.3952 - g_loss: 1.5428
# Epoch 1136/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3974 - g_loss: 1.5459
# Epoch 1137/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3938 - g_loss: 1.5690
# Epoch 1138/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3940 - g_loss: 1.5460
# Epoch 1139/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3943 - g_loss: 1.5544
# Epoch 1140/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3892 - g_loss: 1.5028
# Epoch 1141/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3950 - g_loss: 1.5612
# Epoch 1142/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3955 - g_loss: 1.5524
# Epoch 1143/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3931 - g_loss: 1.5607
# Epoch 1144/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3948 - g_loss: 1.5516
# Epoch 1145/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3958 - g_loss: 1.5521
# Epoch 1146/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3936 - g_loss: 1.5762
# Epoch 1147/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3940 - g_loss: 1.5692
# Epoch 1148/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3956 - g_loss: 1.5427
# Epoch 1149/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3922 - g_loss: 1.5520
# Epoch 1150/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3956 - g_loss: 1.5614
# Epoch 1151/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3933 - g_loss: 1.5542
# Epoch 1152/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3933 - g_loss: 1.5481
# Epoch 1153/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3948 - g_loss: 1.5568
# Epoch 1154/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3929 - g_loss: 1.5722
# Epoch 1155/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3904 - g_loss: 1.5688
# Epoch 1156/3500
# 197/197 [==============================] - 3s 17ms/step - d_loss: 0.3917 - g_loss: 1.5552
# Epoch 1157/3500
# 197/197 [==============================] - 11s 58ms/step - d_loss: 0.3946 - g_loss: 1.5326
# Epoch 1158/3500
# 197/197 [==============================] - 10s 49ms/step - d_loss: 0.3924 - g_loss: 1.5790
# Epoch 1159/3500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3921 - g_loss: 1.5693
# Epoch 1160/3500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3933 - g_loss: 1.5726
# Epoch 1161/3500
#  72/197 [=========>....................] - ETA: 1s - d_loss: 0.3915 - g_loss: 1.5659
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\telab\OneDrive - 独立行政法人 国立高等専門学校機構\Lepa\GANs\Basic_1D.ipynb Cell 12 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_1D.ipynb#ch0000011?line=2'>3</a> gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_1D.ipynb#ch0000011?line=3'>4</a> gan.compile(
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_1D.ipynb#ch0000011?line=4'>5</a>     d_optimizer=keras.optimizers.Adam(learning_rate=0.00001, beta_1=0.5),
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_1D.ipynb#ch0000011?line=5'>6</a>     g_optimizer=keras.optimizers.Adam(learning_rate=0.00001, beta_1=0.5),
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_1D.ipynb#ch0000011?line=6'>7</a>     loss_fn=keras.losses.BinaryCrossentropy(),
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_1D.ipynb#ch0000011?line=7'>8</a> )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_1D.ipynb#ch0000011?line=9'>10</a> gan.fit(
#      <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_1D.ipynb#ch0000011?line=10'>11</a>     train_dataset, epochs=epochs, callbacks=[GANMonitor(num_img=1, latent_dim=latent_dim), model_checkpoint_callback]
#      <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_1D.ipynb#ch0000011?line=11'>12</a> )
#
# File c:\Users\telab\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\telab\anaconda3\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
