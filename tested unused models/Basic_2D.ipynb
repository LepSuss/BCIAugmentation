# %%
from scipy.io import loadmat
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pymatreader import read_mat
import tensorflow as tf
from tensorflow import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import eeg_funcs

# %%
filepath = glob('data/train/*.mat')
d_array, d_labels = eeg_funcs.get_comp2_array(filepath, False, True)
print(d_array.shape)
# Out:
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=29568
#     Range : 0 ... 29567 =      0.000 ...   123.196 secs
# Ready.
# 541 events found
# Event IDs: [1 2]
# Not setting metadata
# 541 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 541 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=29568
#     Range : 0 ... 29567 =      0.000 ...   123.196 secs
# Ready.
# 541 events found
# Event IDs: [1 2]
# Not setting metadata
# 541 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 541 events and 160 original time points ...
# 0 bad epochs dropped
# (12600, 160, 8)

# %%
def normalize_data(data):
    data = (data - np.min(data)) / (np.max(data) - np.min(data))
    result = 2 * data - 1
    result = np.float32(result)
    return result

# %%
d_array = d_array*1e6
d_array = normalize_data(d_array)
print(d_array.shape)
# Out:
# (12600, 160, 8)

# %%
d_array = tf.expand_dims(d_array, axis=3)
print(d_array.shape)
print(type(d_array))
# Out:
# (12600, 160, 8, 1)
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
data_array = d_array
data_array = tf.convert_to_tensor(data_array, dtype=tf.float32)

# %%
plt.plot(d_array[2564,:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x1634923bc40>,
#  <matplotlib.lines.Line2D at 0x1634923bb80>,
#  <matplotlib.lines.Line2D at 0x1634923ba90>,
#  <matplotlib.lines.Line2D at 0x1634923b970>,
#  <matplotlib.lines.Line2D at 0x1634923b850>,
#  <matplotlib.lines.Line2D at 0x1634923b730>,
#  <matplotlib.lines.Line2D at 0x1634923b610>,
#  <matplotlib.lines.Line2D at 0x1634923b4f0>]

# %%
BUFFER_SIZE = 30000
BATCH_SIZE = 128
train_dataset = tf.data.Dataset.from_tensor_slices(data_array).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %%
discriminator = keras.Sequential(
    [
        keras.Input(shape=data_array.shape[1:]),
        layers.Conv2D(64, kernel_size=(4,4), strides=(2,2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.2),
        layers.Conv2D(128, kernel_size=(4,4), strides=(2,2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(1, activation="sigmoid"),
    ],
    name="discriminator",
)
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 80, 4, 64)         1088
#
#  leaky_re_lu (LeakyReLU)     (None, 80, 4, 64)         0
#
#  dropout (Dropout)           (None, 80, 4, 64)         0
#
#  conv2d_1 (Conv2D)           (None, 40, 2, 128)        131200
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 40, 2, 128)        0
#
#  dropout_1 (Dropout)         (None, 40, 2, 128)        0
#
#  flatten (Flatten)           (None, 10240)             0
#
#  dense (Dense)               (None, 1)                 10241
#
# =================================================================
# Total params: 142,529
# Trainable params: 142,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
latent_dim = 160

generator = keras.Sequential(
    [
        keras.Input(shape=(latent_dim,)),
        layers.Dense(5*2*256, use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),
        layers.Reshape((5, 2, 256)),
        layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2DTranspose(64, (4, 4), strides=(4, 2), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2DTranspose(1, (4, 4), strides=(2, 1), padding='same', use_bias=False, activation='tanh'),
    ],
    name="generator",
)
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 2560)              409600
#
#  batch_normalization_9 (Batc  (None, 2560)             10240
#  hNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 2560)              0
#
#  reshape_3 (Reshape)         (None, 5, 2, 256)         0
#
#  conv2d_transpose_9 (Conv2DT  (None, 20, 4, 128)       524288
#  ranspose)
#
#  batch_normalization_10 (Bat  (None, 20, 4, 128)       512
#  chNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 20, 4, 128)        0
#
#  conv2d_transpose_10 (Conv2D  (None, 80, 8, 64)        131072
#  Transpose)
#
#  batch_normalization_11 (Bat  (None, 80, 8, 64)        256
#  chNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 80, 8, 64)         0
#
#  conv2d_transpose_11 (Conv2D  (None, 160, 8, 1)        1024
#  Transpose)
#
# =================================================================
# Total params: 1,076,992
# Trainable params: 1,071,488
# Non-trainable params: 5,504
# _________________________________________________________________

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn
        self.d_loss_metric = keras.metrics.Mean(name="d_loss")
        self.g_loss_metric = keras.metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, real_images):
        # Sample random points in the latent space
        batch_size = tf.shape(real_images)[0]
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        # Decode them to fake images
        generated_images = self.generator(random_latent_vectors)

        # Combine them with real images
        combined_images = tf.concat([generated_images, real_images], axis=0)

        # Assemble labels discriminating real from fake images
        labels = tf.concat(
            [tf.ones((batch_size, 1)), tf.zeros((batch_size, 1))], axis=0
        )
        # Add random noise to the labels - important trick!
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # Train the discriminator
        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_images)
            d_loss = self.loss_fn(labels, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(zip(grads, self.discriminator.trainable_weights))

        # Sample random points in the latent space
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        # Assemble labels that say "all real images"
        misleading_labels = tf.zeros((batch_size, 1))

        # Train the generator (note that we should *not* update the weights
        # of the discriminator)!
        with tf.GradientTape() as tape:
            predictions = self.discriminator(self.generator(random_latent_vectors))
            g_loss = self.loss_fn(misleading_labels, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Update metrics
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)
        return {
            "d_loss": self.d_loss_metric.result(),
            "g_loss": self.g_loss_metric.result(),
        }

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=1, latent_dim=100):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator(random_latent_vectors)
        generated_images.numpy()
        for i in range(self.num_img):
            img = generated_images[i]
            img1 = img[:,:,0]
            img2 = img[:,5,:]
            plt.plot(img2)
            plt.savefig("B2Dtestimages/P300/single/generated_img_%03d_%d.png" % (epoch, i))
            plt.clf()
            plt.plot(img1)
            plt.savefig("B2Dtestimages/P300/full/generated_img_%03d_%d.png" % (epoch, i))
            plt.clf()
            ##img = keras.preprocessing.image.array_to_img(generated_images[i])
            ##img.save("generated_img_%03d_%d.png" % (epoch, i))

# %%
checkpoint_filepath = 'checkpointB2D/P300/checkpoint.{epoch:02d}'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='g_loss',
    mode='min',
    save_best_only=True)

# %%
epochs = 1000  # In practice, use ~100 epochs

gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.00001, beta_1=0.5),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.00001, beta_1=0.5),
    loss_fn=keras.losses.BinaryCrossentropy(from_logits=False),
)

gan.fit(
    train_dataset, epochs=epochs, callbacks=[GANMonitor(num_img=1, latent_dim=latent_dim), model_checkpoint_callback]
)
# Out:
# Epoch 1/1000
# 99/99 [==============================] - 3s 13ms/step - d_loss: 0.6226 - g_loss: 1.2379
# Epoch 2/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.5041 - g_loss: 1.4623
# Epoch 3/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7534
# Epoch 4/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6962 - g_loss: 0.7480
# Epoch 5/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7481
# Epoch 6/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6938 - g_loss: 0.7535
# Epoch 7/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6918 - g_loss: 0.7551
# Epoch 8/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6943 - g_loss: 0.7564
# Epoch 9/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6936 - g_loss: 0.7590
# Epoch 10/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6955 - g_loss: 0.7490
# Epoch 11/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6969 - g_loss: 0.7642
# Epoch 12/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6977 - g_loss: 0.7685
# Epoch 13/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6947 - g_loss: 0.7601
# Epoch 14/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.7001 - g_loss: 0.7564
# Epoch 15/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6979 - g_loss: 0.7548
# Epoch 16/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6976 - g_loss: 0.7645
# Epoch 17/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6943 - g_loss: 0.7596
# Epoch 18/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6996 - g_loss: 0.7644
# Epoch 19/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6963 - g_loss: 0.7563
# Epoch 20/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6924 - g_loss: 0.7604
# Epoch 21/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6990 - g_loss: 0.7554
# Epoch 22/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6943 - g_loss: 0.7709
# Epoch 23/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.7006 - g_loss: 0.7558
# Epoch 24/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7607
# Epoch 25/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.7003 - g_loss: 0.7607
# Epoch 26/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6902 - g_loss: 0.7662
# Epoch 27/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.7018 - g_loss: 0.7657
# Epoch 28/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7662
# Epoch 29/1000
# 99/99 [==============================] - 1s 14ms/step - d_loss: 0.6967 - g_loss: 0.7517
# Epoch 30/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6922 - g_loss: 0.7649
# Epoch 31/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.7006 - g_loss: 0.7524
# Epoch 32/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6913 - g_loss: 0.7674
# Epoch 33/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.7007 - g_loss: 0.7641
# Epoch 34/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6933 - g_loss: 0.7619
# Epoch 35/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6965 - g_loss: 0.7567
# Epoch 36/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6940 - g_loss: 0.7536
# Epoch 37/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6943 - g_loss: 0.7609
# Epoch 38/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6959 - g_loss: 0.7494
# Epoch 39/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6928 - g_loss: 0.7550
# Epoch 40/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6955 - g_loss: 0.7632
# Epoch 41/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6952 - g_loss: 0.7608
# Epoch 42/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6975 - g_loss: 0.7540
# Epoch 43/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6971 - g_loss: 0.7610
# Epoch 44/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6932 - g_loss: 0.7612
# Epoch 45/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6954 - g_loss: 0.7854
# Epoch 46/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6990 - g_loss: 0.7580
# Epoch 47/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6933 - g_loss: 0.7607
# Epoch 48/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6933 - g_loss: 0.7623
# Epoch 49/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6952 - g_loss: 0.7519
# Epoch 50/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6960 - g_loss: 0.7560
# Epoch 51/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6952 - g_loss: 0.7554
# Epoch 52/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6947 - g_loss: 0.7597
# Epoch 53/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6949 - g_loss: 0.7598
# Epoch 54/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6946 - g_loss: 0.7489
# Epoch 55/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6937 - g_loss: 0.7573
# Epoch 56/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6896 - g_loss: 0.7556
# Epoch 57/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6966 - g_loss: 0.7562
# Epoch 58/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6936 - g_loss: 0.7494
# Epoch 59/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6962 - g_loss: 0.7600
# Epoch 60/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6944 - g_loss: 0.7626
# Epoch 61/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6948 - g_loss: 0.7566
# Epoch 62/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6937 - g_loss: 0.7520
# Epoch 63/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6931 - g_loss: 0.7592
# Epoch 64/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6930 - g_loss: 0.7518
# Epoch 65/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6927 - g_loss: 0.7531
# Epoch 66/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6939 - g_loss: 0.7680
# Epoch 67/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6970 - g_loss: 0.7575
# Epoch 68/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6940 - g_loss: 0.7621
# Epoch 69/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6955 - g_loss: 0.7523
# Epoch 70/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6916 - g_loss: 0.7563
# Epoch 71/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7536
# Epoch 72/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6938 - g_loss: 0.7610
# Epoch 73/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6949 - g_loss: 0.7537
# Epoch 74/1000
# 99/99 [==============================] - 1s 15ms/step - d_loss: 0.6920 - g_loss: 0.7626
# Epoch 75/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7532
# Epoch 76/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6939 - g_loss: 0.7583
# Epoch 77/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.7007 - g_loss: 0.7585
# Epoch 78/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6925 - g_loss: 0.7642
# Epoch 79/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6930 - g_loss: 0.7636
# Epoch 80/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.7018 - g_loss: 0.7691
# Epoch 81/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6942 - g_loss: 0.7616
# Epoch 82/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6963 - g_loss: 0.7533
# Epoch 83/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6922 - g_loss: 0.7635
# Epoch 84/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6955 - g_loss: 0.7573
# Epoch 85/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7713
# Epoch 86/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.7001 - g_loss: 0.7535
# Epoch 87/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6936 - g_loss: 0.7545
# Epoch 88/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6961 - g_loss: 0.7597
# Epoch 89/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7586
# Epoch 90/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7596
# Epoch 91/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6922 - g_loss: 0.7589
# Epoch 92/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6918 - g_loss: 0.7542
# Epoch 93/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6939 - g_loss: 0.7570
# Epoch 94/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6962 - g_loss: 0.7564
# Epoch 95/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6960 - g_loss: 0.7569
# Epoch 96/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6912 - g_loss: 0.7586
# Epoch 97/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6938 - g_loss: 0.7643
# Epoch 98/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6952 - g_loss: 0.7583
# Epoch 99/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6916 - g_loss: 0.7534
# Epoch 100/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6928 - g_loss: 0.7585
# Epoch 101/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6965 - g_loss: 0.7579
# Epoch 102/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6931 - g_loss: 0.7568
# Epoch 103/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6924 - g_loss: 0.7583
# Epoch 104/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6988 - g_loss: 0.7607
# Epoch 105/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6966 - g_loss: 0.7584
# Epoch 106/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7560
# Epoch 107/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6952 - g_loss: 0.7552
# Epoch 108/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6950 - g_loss: 0.7521
# Epoch 109/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6941 - g_loss: 0.7529
# Epoch 110/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6912 - g_loss: 0.7526
# Epoch 111/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6955 - g_loss: 0.7563
# Epoch 112/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7584
# Epoch 113/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7510
# Epoch 114/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6891 - g_loss: 0.7574
# Epoch 115/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6913 - g_loss: 0.7548
# Epoch 116/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6941 - g_loss: 0.7570
# Epoch 117/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6927 - g_loss: 0.7577
# Epoch 118/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6941 - g_loss: 0.7554
# Epoch 119/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6916 - g_loss: 0.7518
# Epoch 120/1000
# 99/99 [==============================] - 1s 15ms/step - d_loss: 0.6876 - g_loss: 0.7513
# Epoch 121/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6906 - g_loss: 0.7525
# Epoch 122/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6906 - g_loss: 0.7576
# Epoch 123/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6882 - g_loss: 0.7575
# Epoch 124/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6924 - g_loss: 0.7569
# Epoch 125/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6953 - g_loss: 0.7520
# Epoch 126/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6945 - g_loss: 0.7503
# Epoch 127/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6938 - g_loss: 0.7539
# Epoch 128/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6939 - g_loss: 0.7608
# Epoch 129/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6901 - g_loss: 0.7481
# Epoch 130/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6912 - g_loss: 0.7503
# Epoch 131/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6919 - g_loss: 0.7502
# Epoch 132/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6953 - g_loss: 0.7550
# Epoch 133/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6949 - g_loss: 0.7540
# Epoch 134/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6942 - g_loss: 0.7620
# Epoch 135/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6944 - g_loss: 0.7510
# Epoch 136/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6920 - g_loss: 0.7508
# Epoch 137/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6944 - g_loss: 0.7575
# Epoch 138/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6949 - g_loss: 0.7522
# Epoch 139/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6906 - g_loss: 0.7560
# Epoch 140/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6950 - g_loss: 0.7505
# Epoch 141/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6921 - g_loss: 0.7525
# Epoch 142/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6920 - g_loss: 0.7522
# Epoch 143/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6931 - g_loss: 0.7550
# Epoch 144/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6930 - g_loss: 0.7565
# Epoch 145/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6928 - g_loss: 0.7536
# Epoch 146/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6932 - g_loss: 0.7514
# Epoch 147/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6940 - g_loss: 0.7527
# Epoch 148/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6919 - g_loss: 0.7513
# Epoch 149/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6896 - g_loss: 0.7549
# Epoch 150/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6932 - g_loss: 0.7540
# Epoch 151/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6924 - g_loss: 0.7499
# Epoch 152/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6911 - g_loss: 0.7507
# Epoch 153/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6917 - g_loss: 0.7509
# Epoch 154/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6887 - g_loss: 0.7588
# Epoch 155/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6913 - g_loss: 0.7556
# Epoch 156/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6934 - g_loss: 0.7553
# Epoch 157/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6958 - g_loss: 0.7613
# Epoch 158/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6912 - g_loss: 0.7590
# Epoch 159/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6914 - g_loss: 0.7451
# Epoch 160/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6928 - g_loss: 0.7499
# Epoch 161/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6941 - g_loss: 0.7526
# Epoch 162/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6927 - g_loss: 0.7501
# Epoch 163/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6938 - g_loss: 0.7561
# Epoch 164/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6902 - g_loss: 0.7609
# Epoch 165/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6920 - g_loss: 0.7634
# Epoch 166/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6942 - g_loss: 0.7502
# Epoch 167/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6925 - g_loss: 0.7471
# Epoch 168/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6921 - g_loss: 0.7557
# Epoch 169/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6900 - g_loss: 0.7519
# Epoch 170/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6933 - g_loss: 0.7511
# Epoch 171/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6912 - g_loss: 0.7502
# Epoch 172/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6918 - g_loss: 0.7527
# Epoch 173/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6946 - g_loss: 0.7510
# Epoch 174/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6934 - g_loss: 0.7601
# Epoch 175/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6912 - g_loss: 0.7598
# Epoch 176/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6941 - g_loss: 0.7520
# Epoch 177/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6951 - g_loss: 0.7523
# Epoch 178/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6938 - g_loss: 0.7604
# Epoch 179/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6906 - g_loss: 0.7568
# Epoch 180/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6923 - g_loss: 0.7487
# Epoch 181/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6911 - g_loss: 0.7609
# Epoch 182/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6927 - g_loss: 0.7525
# Epoch 183/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6909 - g_loss: 0.7517
# Epoch 184/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6916 - g_loss: 0.7550
# Epoch 185/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6934 - g_loss: 0.7492
# Epoch 186/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6912 - g_loss: 0.7541
# Epoch 187/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6921 - g_loss: 0.7513
# Epoch 188/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6936 - g_loss: 0.7494
# Epoch 189/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6932 - g_loss: 0.7543
# Epoch 190/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6946 - g_loss: 0.7564
# Epoch 191/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6954 - g_loss: 0.7516
# Epoch 192/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6920 - g_loss: 0.7682
# Epoch 193/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6941 - g_loss: 0.7464
# Epoch 194/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6916 - g_loss: 0.7569
# Epoch 195/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6899 - g_loss: 0.7530
# Epoch 196/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6952 - g_loss: 0.7560
# Epoch 197/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6922 - g_loss: 0.7497
# Epoch 198/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6925 - g_loss: 0.7520
# Epoch 199/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6942 - g_loss: 0.7494
# Epoch 200/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6986 - g_loss: 0.7653
# Epoch 201/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6918 - g_loss: 0.7570
# Epoch 202/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6907 - g_loss: 0.7551
# Epoch 203/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6932 - g_loss: 0.7531
# Epoch 204/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6924 - g_loss: 0.7508
# Epoch 205/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6936 - g_loss: 0.7508
# Epoch 206/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6921 - g_loss: 0.7509
# Epoch 207/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6924 - g_loss: 0.7565
# Epoch 208/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6953 - g_loss: 0.7508
# Epoch 209/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6932 - g_loss: 0.7546
# Epoch 210/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6927 - g_loss: 0.7570
# Epoch 211/1000
# 99/99 [==============================] - 1s 14ms/step - d_loss: 0.6936 - g_loss: 0.7539
# Epoch 212/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6962 - g_loss: 0.7448
# Epoch 213/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6912 - g_loss: 0.7621
# Epoch 214/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6940 - g_loss: 0.7443
# Epoch 215/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6912 - g_loss: 0.7612
# Epoch 216/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6931 - g_loss: 0.7514
# Epoch 217/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6930 - g_loss: 0.7502
# Epoch 218/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6889 - g_loss: 0.7569
# Epoch 219/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6917 - g_loss: 0.7446
# Epoch 220/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6921 - g_loss: 0.7521
# Epoch 221/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6936 - g_loss: 0.7517
# Epoch 222/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6939 - g_loss: 0.7516
# Epoch 223/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6922 - g_loss: 0.7553
# Epoch 224/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6937 - g_loss: 0.7585
# Epoch 225/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6972 - g_loss: 0.7488
# Epoch 226/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6951 - g_loss: 0.7563
# Epoch 227/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6918 - g_loss: 0.7570
# Epoch 228/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6915 - g_loss: 0.7545
# Epoch 229/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6908 - g_loss: 0.7552
# Epoch 230/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6902 - g_loss: 0.7490
# Epoch 231/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6925 - g_loss: 0.7501
# Epoch 232/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6935 - g_loss: 0.7569
# Epoch 233/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6927 - g_loss: 0.7479
# Epoch 234/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6927 - g_loss: 0.7486
# Epoch 235/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6911 - g_loss: 0.7524
# Epoch 236/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6937 - g_loss: 0.7522
# Epoch 237/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6941 - g_loss: 0.7483
# Epoch 238/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6941 - g_loss: 0.7591
# Epoch 239/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6923 - g_loss: 0.7549
# Epoch 240/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6893 - g_loss: 0.7628
# Epoch 241/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6949 - g_loss: 0.7439
# Epoch 242/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6964 - g_loss: 0.7715
# Epoch 243/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6964 - g_loss: 0.7484
# Epoch 244/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6910 - g_loss: 0.7584
# Epoch 245/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6894 - g_loss: 0.7512
# Epoch 246/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6897 - g_loss: 0.7533
# Epoch 247/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6914 - g_loss: 0.7480
# Epoch 248/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6914 - g_loss: 0.7496
# Epoch 249/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6914 - g_loss: 0.7478
# Epoch 250/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6917 - g_loss: 0.7504
# Epoch 251/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6917 - g_loss: 0.7509
# Epoch 252/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6940 - g_loss: 0.7494
# Epoch 253/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6928 - g_loss: 0.7488
# Epoch 254/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6923 - g_loss: 0.7535
# Epoch 255/1000
# 99/99 [==============================] - 1s 14ms/step - d_loss: 0.6927 - g_loss: 0.7526
# Epoch 256/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6941 - g_loss: 0.7500
# Epoch 257/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6912 - g_loss: 0.7516
# Epoch 258/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6916 - g_loss: 0.7554
# Epoch 259/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6931 - g_loss: 0.7537
# Epoch 260/1000
# 99/99 [==============================] - 1s 14ms/step - d_loss: 0.6946 - g_loss: 0.7514
# Epoch 261/1000
# 99/99 [==============================] - 1s 14ms/step - d_loss: 0.6924 - g_loss: 0.7489
# Epoch 262/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7531
# Epoch 263/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6916 - g_loss: 0.7584
# Epoch 264/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6954 - g_loss: 0.7534
# Epoch 265/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6947 - g_loss: 0.7558
# Epoch 266/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6936 - g_loss: 0.7533
# Epoch 267/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6905 - g_loss: 0.7544
# Epoch 268/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6918 - g_loss: 0.7638
# Epoch 269/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7423
# Epoch 270/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6945 - g_loss: 0.7580
# Epoch 271/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6921 - g_loss: 0.7502
# Epoch 272/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6921 - g_loss: 0.7523
# Epoch 273/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6903 - g_loss: 0.7622
# Epoch 274/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6938 - g_loss: 0.7462
# Epoch 275/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6924 - g_loss: 0.7568
# Epoch 276/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6921 - g_loss: 0.7501
# Epoch 277/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6934 - g_loss: 0.7518
# Epoch 278/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6921 - g_loss: 0.7501
# Epoch 279/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7502
# Epoch 280/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6918 - g_loss: 0.7528
# Epoch 281/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7545
# Epoch 282/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6935 - g_loss: 0.7538
# Epoch 283/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6928 - g_loss: 0.7479
# Epoch 284/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6941 - g_loss: 0.7503
# Epoch 285/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6913 - g_loss: 0.7523
# Epoch 286/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6928 - g_loss: 0.7489
# Epoch 287/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6925 - g_loss: 0.7503
# Epoch 288/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6894 - g_loss: 0.7499
# Epoch 289/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6921 - g_loss: 0.7499
# Epoch 290/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6954 - g_loss: 0.7552
# Epoch 291/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6905 - g_loss: 0.7533
# Epoch 292/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6951 - g_loss: 0.7499
# Epoch 293/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7575
# Epoch 294/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7544
# Epoch 295/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6922 - g_loss: 0.7563
# Epoch 296/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6939 - g_loss: 0.7490
# Epoch 297/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6951 - g_loss: 0.7637
# Epoch 298/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6962 - g_loss: 0.7522
# Epoch 299/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6911 - g_loss: 0.7638
# Epoch 300/1000
# 99/99 [==============================] - 1s 15ms/step - d_loss: 0.6917 - g_loss: 0.7469
# Epoch 301/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6928 - g_loss: 0.7583
# Epoch 302/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6912 - g_loss: 0.7541
# Epoch 303/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6931 - g_loss: 0.7548
# Epoch 304/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6941 - g_loss: 0.7472
# Epoch 305/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6890 - g_loss: 0.7551
# Epoch 306/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6942 - g_loss: 0.7461
# Epoch 307/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6915 - g_loss: 0.7542
# Epoch 308/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6907 - g_loss: 0.7513
# Epoch 309/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6932 - g_loss: 0.7498
# Epoch 310/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7482
# Epoch 311/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6927 - g_loss: 0.7471
# Epoch 312/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6916 - g_loss: 0.7521
# Epoch 313/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6924 - g_loss: 0.7495
# Epoch 314/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7502
# Epoch 315/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6950 - g_loss: 0.7499
# Epoch 316/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6939 - g_loss: 0.7491
# Epoch 317/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7583
# Epoch 318/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7507
# Epoch 319/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6928 - g_loss: 0.7479
# Epoch 320/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6904 - g_loss: 0.7526
# Epoch 321/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6914 - g_loss: 0.7527
# Epoch 322/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7485
# Epoch 323/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7535
# Epoch 324/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7479
# Epoch 325/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7468
# Epoch 326/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6917 - g_loss: 0.7503
# Epoch 327/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6939 - g_loss: 0.7540
# Epoch 328/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6918 - g_loss: 0.7491
# Epoch 329/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6931 - g_loss: 0.7558
# Epoch 330/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6908 - g_loss: 0.7527
# Epoch 331/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6941 - g_loss: 0.7544
# Epoch 332/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6911 - g_loss: 0.7522
# Epoch 333/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6927 - g_loss: 0.7538
# Epoch 334/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7504
# Epoch 335/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6910 - g_loss: 0.7534
# Epoch 336/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6921 - g_loss: 0.7512
# Epoch 337/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6930 - g_loss: 0.7456
# Epoch 338/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6930 - g_loss: 0.7538
# Epoch 339/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6913 - g_loss: 0.7561
# Epoch 340/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6937 - g_loss: 0.7498
# Epoch 341/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6928 - g_loss: 0.7492
# Epoch 342/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6940 - g_loss: 0.7498
# Epoch 343/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6907 - g_loss: 0.7495
# Epoch 344/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6900 - g_loss: 0.7500
# Epoch 345/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6938 - g_loss: 0.7494
# Epoch 346/1000
# 99/99 [==============================] - 1s 15ms/step - d_loss: 0.6912 - g_loss: 0.7521
# Epoch 347/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6937 - g_loss: 0.7473
# Epoch 348/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6934 - g_loss: 0.7512
# Epoch 349/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6940 - g_loss: 0.7522
# Epoch 350/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6930 - g_loss: 0.7559
# Epoch 351/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6904 - g_loss: 0.7490
# Epoch 352/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7584
# Epoch 353/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6957 - g_loss: 0.7482
# Epoch 354/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6898 - g_loss: 0.7635
# Epoch 355/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6944 - g_loss: 0.7501
# Epoch 356/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6943 - g_loss: 0.7579
# Epoch 357/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6935 - g_loss: 0.7509
# Epoch 358/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7547
# Epoch 359/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6941 - g_loss: 0.7547
# Epoch 360/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6923 - g_loss: 0.7530
# Epoch 361/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7537
# Epoch 362/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6908 - g_loss: 0.7621
# Epoch 363/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6936 - g_loss: 0.7454
# Epoch 364/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7523
# Epoch 365/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7569
# Epoch 366/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6939 - g_loss: 0.7529
# Epoch 367/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6937 - g_loss: 0.7518
# Epoch 368/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6903 - g_loss: 0.7501
# Epoch 369/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6948 - g_loss: 0.7468
# Epoch 370/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6922 - g_loss: 0.7503
# Epoch 371/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6925 - g_loss: 0.7584
# Epoch 372/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6936 - g_loss: 0.7430
# Epoch 373/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6934 - g_loss: 0.7537
# Epoch 374/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6902 - g_loss: 0.7534
# Epoch 375/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6906 - g_loss: 0.7476
# Epoch 376/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6941 - g_loss: 0.7510
# Epoch 377/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6911 - g_loss: 0.7493
# Epoch 378/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6931 - g_loss: 0.7457
# Epoch 379/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6930 - g_loss: 0.7497
# Epoch 380/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6918 - g_loss: 0.7506
# Epoch 381/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6950 - g_loss: 0.7499
# Epoch 382/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6899 - g_loss: 0.7558
# Epoch 383/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6917 - g_loss: 0.7499
# Epoch 384/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6964 - g_loss: 0.7534
# Epoch 385/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7529
# Epoch 386/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6924 - g_loss: 0.7556
# Epoch 387/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7509
# Epoch 388/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7487
# Epoch 389/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6918 - g_loss: 0.7486
# Epoch 390/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6943 - g_loss: 0.7527
# Epoch 391/1000
# 99/99 [==============================] - 1s 15ms/step - d_loss: 0.6935 - g_loss: 0.7495
# Epoch 392/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6909 - g_loss: 0.7545
# Epoch 393/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6932 - g_loss: 0.7537
# Epoch 394/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6936 - g_loss: 0.7512
# Epoch 395/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6908 - g_loss: 0.7550
# Epoch 396/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6914 - g_loss: 0.7628
# Epoch 397/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6958 - g_loss: 0.7508
# Epoch 398/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6912 - g_loss: 0.7513
# Epoch 399/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7560
# Epoch 400/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6944 - g_loss: 0.7503
# Epoch 401/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6917 - g_loss: 0.7551
# Epoch 402/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6943 - g_loss: 0.7513
# Epoch 403/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6925 - g_loss: 0.7516
# Epoch 404/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6915 - g_loss: 0.7501
# Epoch 405/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6929 - g_loss: 0.7446
# Epoch 406/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6913 - g_loss: 0.7520
# Epoch 407/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6925 - g_loss: 0.7430
# Epoch 408/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6933 - g_loss: 0.7534
# Epoch 409/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6948 - g_loss: 0.7461
# Epoch 410/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6906 - g_loss: 0.7510
# Epoch 411/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6954 - g_loss: 0.7538
# Epoch 412/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6915 - g_loss: 0.7607
# Epoch 413/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6933 - g_loss: 0.7477
# Epoch 414/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6941 - g_loss: 0.7612
# Epoch 415/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6925 - g_loss: 0.7509
# Epoch 416/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6963 - g_loss: 0.7531
# Epoch 417/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6893 - g_loss: 0.7524
# Epoch 418/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6955 - g_loss: 0.7523
# Epoch 419/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6932 - g_loss: 0.7564
# Epoch 420/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6888 - g_loss: 0.7530
# Epoch 421/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6927 - g_loss: 0.7483
# Epoch 422/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6933 - g_loss: 0.7489
# Epoch 423/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6933 - g_loss: 0.7535
# Epoch 424/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6918 - g_loss: 0.7565
# Epoch 425/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6948 - g_loss: 0.7485
# Epoch 426/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6957 - g_loss: 0.7541
# Epoch 427/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7628
# Epoch 428/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6910 - g_loss: 0.7506
# Epoch 429/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6932 - g_loss: 0.7592
# Epoch 430/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6928 - g_loss: 0.7568
# Epoch 431/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6899 - g_loss: 0.7496
# Epoch 432/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6941 - g_loss: 0.7530
# Epoch 433/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7486
# Epoch 434/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7495
# Epoch 435/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7528
# Epoch 436/1000
# 99/99 [==============================] - 1s 15ms/step - d_loss: 0.6923 - g_loss: 0.7473
# Epoch 437/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6927 - g_loss: 0.7498
# Epoch 438/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6938 - g_loss: 0.7457
# Epoch 439/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6899 - g_loss: 0.7553
# Epoch 440/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6914 - g_loss: 0.7464
# Epoch 441/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6927 - g_loss: 0.7562
# Epoch 442/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6913 - g_loss: 0.7479
# Epoch 443/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6933 - g_loss: 0.7563
# Epoch 444/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6933 - g_loss: 0.7453
# Epoch 445/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6942 - g_loss: 0.7532
# Epoch 446/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6910 - g_loss: 0.7553
# Epoch 447/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7532
# Epoch 448/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6903 - g_loss: 0.7543
# Epoch 449/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6925 - g_loss: 0.7579
# Epoch 450/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7469
# Epoch 451/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6912 - g_loss: 0.7516
# Epoch 452/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7526
# Epoch 453/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6915 - g_loss: 0.7496
# Epoch 454/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6915 - g_loss: 0.7512
# Epoch 455/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7489
# Epoch 456/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6928 - g_loss: 0.7502
# Epoch 457/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6944 - g_loss: 0.7528
# Epoch 458/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6934 - g_loss: 0.7531
# Epoch 459/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6918 - g_loss: 0.7495
# Epoch 460/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6921 - g_loss: 0.7559
# Epoch 461/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6924 - g_loss: 0.7481
# Epoch 462/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6927 - g_loss: 0.7476
# Epoch 463/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6918 - g_loss: 0.7526
# Epoch 464/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6928 - g_loss: 0.7489
# Epoch 465/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6942 - g_loss: 0.7460
# Epoch 466/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6907 - g_loss: 0.7534
# Epoch 467/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6949 - g_loss: 0.7499
# ...
# Epoch 709/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6941 - g_loss: 0.7515
# Epoch 710/1000
# 99/99 [==============================] - 1s 14ms/step - d_loss: 0.6928 - g_loss: 0.7521
# Epoch 711/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6926 - g_loss: 0.7574
# Epoch 712/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6937 - g_loss: 0.7490
# Epoch 713/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6900 - g_loss: 0.7500
# Epoch 714/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6933 - g_loss: 0.7505
# Epoch 715/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6917 - g_loss: 0.7471
# Epoch 716/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6924 - g_loss: 0.7444
# Epoch 717/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6924 - g_loss: 0.7500
# Epoch 718/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6914 - g_loss: 0.7484
# Epoch 719/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6934 - g_loss: 0.7483
# Epoch 720/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6922 - g_loss: 0.7506
# Epoch 721/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6944 - g_loss: 0.7484
# Epoch 722/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6918 - g_loss: 0.7517
# Epoch 723/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7580
# Epoch 724/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6935 - g_loss: 0.7471
# Epoch 725/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6936 - g_loss: 0.7539
# Epoch 726/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6943 - g_loss: 0.7493
# Epoch 727/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6913 - g_loss: 0.7567
# Epoch 728/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6949 - g_loss: 0.7519
# Epoch 729/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7494
# Epoch 730/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6938 - g_loss: 0.7505
# Epoch 731/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6916 - g_loss: 0.7500
# Epoch 732/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6914 - g_loss: 0.7587
# Epoch 733/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6911 - g_loss: 0.7457
# Epoch 734/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6944 - g_loss: 0.7540
# Epoch 735/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6899 - g_loss: 0.7507
# Epoch 736/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6911 - g_loss: 0.7551
# Epoch 737/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6950 - g_loss: 0.7433
# Epoch 738/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6905 - g_loss: 0.7545
# Epoch 739/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7501
# Epoch 740/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6915 - g_loss: 0.7512
# Epoch 741/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7497
# Epoch 742/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6940 - g_loss: 0.7475
# Epoch 743/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6928 - g_loss: 0.7523
# Epoch 744/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6918 - g_loss: 0.7481
# Epoch 745/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7583
# Epoch 746/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6925 - g_loss: 0.7473
# Epoch 747/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6922 - g_loss: 0.7503
# Epoch 748/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6923 - g_loss: 0.7551
# Epoch 749/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6912 - g_loss: 0.7467
# Epoch 750/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6911 - g_loss: 0.7521
# Epoch 751/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7495
# Epoch 752/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6950 - g_loss: 0.7432
# Epoch 753/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6903 - g_loss: 0.7572
# Epoch 754/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6927 - g_loss: 0.7518
# Epoch 755/1000
# 99/99 [==============================] - 1s 15ms/step - d_loss: 0.6941 - g_loss: 0.7534
# Epoch 756/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6920 - g_loss: 0.7479
# Epoch 757/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6936 - g_loss: 0.7536
# Epoch 758/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6930 - g_loss: 0.7459
# Epoch 759/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6914 - g_loss: 0.7494
# Epoch 760/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6931 - g_loss: 0.7529
# Epoch 761/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6909 - g_loss: 0.7560
# Epoch 762/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6929 - g_loss: 0.7478
# Epoch 763/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6931 - g_loss: 0.7524
# Epoch 764/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6943 - g_loss: 0.7546
# Epoch 765/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6910 - g_loss: 0.7521
# Epoch 766/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6962 - g_loss: 0.7532
# Epoch 767/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6916 - g_loss: 0.7559
# Epoch 768/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6958 - g_loss: 0.7553
# Epoch 769/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7531
# Epoch 770/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6933 - g_loss: 0.7579
# Epoch 771/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6948 - g_loss: 0.7499
# Epoch 772/1000
# 99/99 [==============================] - 1s 14ms/step - d_loss: 0.6948 - g_loss: 0.7535
# Epoch 773/1000
# 99/99 [==============================] - 1s 14ms/step - d_loss: 0.6920 - g_loss: 0.7520
# Epoch 774/1000
# 99/99 [==============================] - 1s 14ms/step - d_loss: 0.6903 - g_loss: 0.7552
# Epoch 775/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7498
# Epoch 776/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6923 - g_loss: 0.7498
# Epoch 777/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6937 - g_loss: 0.7484
# Epoch 778/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6934 - g_loss: 0.7481
# Epoch 779/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6902 - g_loss: 0.7562
# Epoch 780/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6944 - g_loss: 0.7480
# Epoch 781/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6919 - g_loss: 0.7472
# Epoch 782/1000
# 99/99 [==============================] - 1s 12ms/step - d_loss: 0.6925 - g_loss: 0.7487
# Epoch 783/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6925 - g_loss: 0.7558
# Epoch 784/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6930 - g_loss: 0.7458
# Epoch 785/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6930 - g_loss: 0.7534
# Epoch 786/1000
# 99/99 [==============================] - 1s 13ms/step - d_loss: 0.6904 - g_loss: 0.7464
# Epoch 787/1000
# 71/99 [====================>.........] - ETA: 0s - d_loss: 0.6929 - g_loss: 0.7506
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\telab\OneDrive - 独立行政法人 国立高等専門学校機構\Lepa\GANs\Basic_2D.ipynb Cell 15 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_2D.ipynb#ch0000014?line=2'>3</a> gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_2D.ipynb#ch0000014?line=3'>4</a> gan.compile(
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_2D.ipynb#ch0000014?line=4'>5</a>     d_optimizer=keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.5),
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_2D.ipynb#ch0000014?line=5'>6</a>     g_optimizer=keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.5),
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_2D.ipynb#ch0000014?line=6'>7</a>     loss_fn=keras.losses.BinaryCrossentropy(from_logits=False),
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_2D.ipynb#ch0000014?line=7'>8</a> )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_2D.ipynb#ch0000014?line=9'>10</a> gan.fit(
#      <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_2D.ipynb#ch0000014?line=10'>11</a>     train_dataset, epochs=epochs, callbacks=[GANMonitor(num_img=1, latent_dim=latent_dim), model_checkpoint_callback]
#      <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Basic_2D.ipynb#ch0000014?line=11'>12</a> )
#
# File c:\Users\telab\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\telab\anaconda3\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
