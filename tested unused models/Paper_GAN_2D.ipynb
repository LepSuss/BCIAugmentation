# %%
from scipy.io import loadmat
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pymatreader import read_mat
import tensorflow as tf
from tensorflow import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import eeg_funcs

# %%
filepath = glob('data/train/*.mat')
d_array, d_labels = eeg_funcs.get_comp2_array(filepath, True, True)
print(d_array.shape)
# Out:
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=29568
#     Range : 0 ... 29567 =      0.000 ...   123.196 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 541 events found
# Event IDs: [1 2]
# Not setting metadata
# 541 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 541 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=26328
#     Range : 0 ... 26327 =      0.000 ...   109.696 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 540 events found
# Event IDs: [1 2]
# Not setting metadata
# 540 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 540 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=43872
#     Range : 0 ... 43871 =      0.000 ...   182.796 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 900 events found
# Event IDs: [1 2]
# Not setting metadata
# 900 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 900 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=35100
#     Range : 0 ... 35099 =      0.000 ...   146.246 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 720 events found
# Event IDs: [1 2]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 720 events and 160 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=65, n_times=29568
#     Range : 0 ... 29567 =      0.000 ...   123.196 secs
# Ready.
# No data channels found. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 32 (effective, after forward-backward)
# - Cutoffs at 0.10, 20.00 Hz: -6.02, -6.02 dB
#
# 541 events found
# Event IDs: [1 2]
# Not setting metadata
# 541 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 541 events and 160 original time points ...
# 0 bad epochs dropped
# (12600, 160, 8)

# %%
def normalize_data(data):
    data = (data - np.min(data)) / (np.max(data) - np.min(data))
    result = 2 * data - 1
    result = np.float32(result)
    return result

# %%
d_array = d_array*1e6
d_array = normalize_data(d_array)
print(d_array.shape)
# Out:
# (12600, 160, 8)

# %%
d_array = tf.expand_dims(d_array, axis=3)
print(d_array.shape)
print(type(d_array))
# Out:
# (12600, 160, 8, 1)
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
data_array_2 = d_array
data_array_2 = tf.convert_to_tensor(data_array_2, dtype=tf.float32)

# %%
BUFFER_SIZE = 30000
BATCH_SIZE = 64
train_dataset = tf.data.Dataset.from_tensor_slices(data_array_2).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %%
discriminator = keras.Sequential(
    [
        keras.Input(shape=data_array_2.shape[1:]),
        layers.Conv2D(8, kernel_size=4, strides=1, padding="same", activation="tanh"),
        layers.MaxPool2D(pool_size=2),
        layers.Conv2D(16, kernel_size=4, strides=1, padding="same", activation="tanh"),
        layers.MaxPool2D(pool_size=2),
        layers.Flatten(),
        layers.Dense(128, activation="tanh"),
        layers.Dense(1, activation="sigmoid"),
    ],
    name="discriminator",
)
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 160, 8, 8)         136
#
#  max_pooling2d_2 (MaxPooling  (None, 80, 4, 8)         0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 80, 4, 16)         2064
#
#  max_pooling2d_3 (MaxPooling  (None, 40, 2, 16)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 128)               163968
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 166,297
# Trainable params: 166,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
latent_dim = 128

generator = keras.Sequential(
    [
        keras.Input(shape=(latent_dim,)),
        layers.Dense(256, activation="tanh"),
        layers.Dense(40*2*1, activation="tanh"),
        layers.BatchNormalization(),
        layers.Reshape((40, 2, 1)),
        layers.UpSampling2D(size=4),
        layers.Conv2D(8, 4, strides=1, padding='same', use_bias=False, activation="tanh"),
        layers.Conv2D(8, 4, strides=1, padding='same', use_bias=False, activation="tanh"),
        layers.Conv2D(1, 4, strides=1, padding='same', use_bias=False, activation="tanh"),
    ],
    name="generator",
)
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 256)               33024
#
#  dense_7 (Dense)             (None, 80)                20560
#
#  batch_normalization_1 (Batc  (None, 80)               320
#  hNormalization)
#
#  reshape_1 (Reshape)         (None, 40, 2, 1)          0
#
#  up_sampling2d_1 (UpSampling  (None, 160, 8, 1)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 160, 8, 8)         128
#
#  conv2d_8 (Conv2D)           (None, 160, 8, 8)         1024
#
#  conv2d_9 (Conv2D)           (None, 160, 8, 1)         128
#
# =================================================================
# Total params: 55,184
# Trainable params: 55,024
# Non-trainable params: 160
# _________________________________________________________________

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn
        self.d_loss_metric = keras.metrics.Mean(name="d_loss")
        self.g_loss_metric = keras.metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, real_images):
        # Sample random points in the latent space
        batch_size = tf.shape(real_images)[0]
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        # Decode them to fake images
        generated_images = self.generator(random_latent_vectors)

        # Combine them with real images
        combined_images = tf.concat([generated_images, real_images], axis=0)

        # Assemble labels discriminating real from fake images
        labels = tf.concat(
            [tf.ones((batch_size, 1)), tf.zeros((batch_size, 1))], axis=0
        )
        # Add random noise to the labels - important trick!
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # Train the discriminator
        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_images)
            d_loss = self.loss_fn(labels, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(zip(grads, self.discriminator.trainable_weights))

        # Sample random points in the latent space
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        # Assemble labels that say "all real images"
        misleading_labels = tf.zeros((batch_size, 1))

        # Train the generator (note that we should *not* update the weights
        # of the discriminator)!
        with tf.GradientTape() as tape:
            predictions = self.discriminator(self.generator(random_latent_vectors))
            g_loss = self.loss_fn(misleading_labels, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Update metrics
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)
        return {
            "d_loss": self.d_loss_metric.result(),
            "g_loss": self.g_loss_metric.result(),
        }

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=1, latent_dim=100):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator(random_latent_vectors)
        generated_images.numpy()
        for i in range(self.num_img):
            img = generated_images[i]
            img1 = img[:,:,0]
            img2 = img[:,5,:]
            plt.plot(img2)
            plt.savefig("Papertestimages/2D//single/generated_img_%03d_%d.png" % (epoch, i))
            plt.clf()
            plt.plot(img1)
            plt.savefig("Papertestimages/2D//full/generated_img_%03d_%d.png" % (epoch, i))
            plt.clf()
            ##img = keras.preprocessing.image.array_to_img(generated_images[i])
            ##img.save("generated_img_%03d_%d.png" % (epoch, i))

# %%
checkpoint_filepath = 'checkpointPaper/2D/checkpoint.{epoch:02d}'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='g_loss',
    mode='min',
    save_best_only=True)

# %%
epochs = 2500  # In practice, use ~100 epochs

gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.2),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.2),
    loss_fn=keras.losses.BinaryCrossentropy(from_logits=False),
)

gan.fit(
    train_dataset, epochs=epochs, callbacks=[GANMonitor(num_img=1, latent_dim=latent_dim), model_checkpoint_callback]
)
# Out:
# Epoch 1/2500
# 197/197 [==============================] - 3s 9ms/step - d_loss: 0.0892 - g_loss: 3.4098
# Epoch 2/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.2191 - g_loss: 3.9373
# Epoch 3/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4803 - g_loss: 1.1646
# Epoch 4/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6491 - g_loss: 0.8209
# Epoch 5/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6334 - g_loss: 0.8317
# Epoch 6/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6278 - g_loss: 0.8373
# Epoch 7/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6690 - g_loss: 0.7856
# Epoch 8/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6870 - g_loss: 0.7595
# Epoch 9/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7073 - g_loss: 0.7426
# Epoch 10/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7002 - g_loss: 0.7490
# Epoch 11/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6842 - g_loss: 0.7645
# Epoch 12/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6879 - g_loss: 0.7623
# Epoch 13/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6752 - g_loss: 0.7791
# Epoch 14/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6802 - g_loss: 0.7744
# Epoch 15/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6800 - g_loss: 0.7690
# Epoch 16/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6809 - g_loss: 0.7919
# Epoch 17/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6888 - g_loss: 0.7643
# Epoch 18/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6937 - g_loss: 0.7675
# Epoch 19/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6834 - g_loss: 0.7794
# Epoch 20/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6785 - g_loss: 0.7847
# Epoch 21/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6907 - g_loss: 0.7764
# Epoch 22/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6734 - g_loss: 0.7881
# Epoch 23/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6630 - g_loss: 0.7903
# Epoch 24/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6987 - g_loss: 0.7677
# Epoch 25/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6764 - g_loss: 0.7794
# Epoch 26/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6795 - g_loss: 0.7790
# Epoch 27/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6755 - g_loss: 0.7867
# Epoch 28/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6729 - g_loss: 0.8108
# Epoch 29/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6902 - g_loss: 0.7735
# Epoch 30/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6908 - g_loss: 0.7695
# Epoch 31/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6880 - g_loss: 0.7647
# Epoch 32/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6473 - g_loss: 0.8726
# Epoch 33/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7121 - g_loss: 0.7535
# Epoch 34/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6776 - g_loss: 0.7794
# Epoch 35/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7003 - g_loss: 0.7589
# Epoch 36/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6937 - g_loss: 0.7645
# Epoch 37/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6192 - g_loss: 0.9991
# Epoch 38/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6949 - g_loss: 0.7573
# Epoch 39/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6797 - g_loss: 0.7891
# Epoch 40/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6825 - g_loss: 0.7908
# Epoch 41/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7056 - g_loss: 0.7522
# Epoch 42/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6831 - g_loss: 0.7787
# Epoch 43/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6978 - g_loss: 0.7508
# Epoch 44/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6737 - g_loss: 0.7892
# Epoch 45/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6827 - g_loss: 0.8008
# Epoch 46/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6539 - g_loss: 0.8202
# Epoch 47/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6909 - g_loss: 0.7895
# Epoch 48/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6774 - g_loss: 0.8016
# Epoch 49/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6683 - g_loss: 0.8136
# Epoch 50/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6877 - g_loss: 0.7724
# Epoch 51/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6950 - g_loss: 0.7639
# Epoch 52/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6564 - g_loss: 0.8362
# Epoch 53/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6754 - g_loss: 0.8109
# Epoch 54/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6752 - g_loss: 0.8046
# Epoch 55/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6817 - g_loss: 0.7995
# Epoch 56/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6819 - g_loss: 0.7980
# Epoch 57/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6868 - g_loss: 0.8128
# Epoch 58/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6947 - g_loss: 0.7786
# Epoch 59/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7040 - g_loss: 0.7601
# Epoch 60/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6335 - g_loss: 0.9743
# Epoch 61/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7102 - g_loss: 0.7331
# Epoch 62/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6875 - g_loss: 0.7666
# Epoch 63/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6903 - g_loss: 0.7619
# Epoch 64/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6745 - g_loss: 0.7806
# Epoch 65/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6820 - g_loss: 0.7934
# Epoch 66/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6805 - g_loss: 0.7877
# Epoch 67/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6787 - g_loss: 0.7863
# Epoch 68/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6892 - g_loss: 0.7850
# Epoch 69/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6817 - g_loss: 0.8234
# Epoch 70/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6870 - g_loss: 0.7886
# Epoch 71/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6922 - g_loss: 0.7744
# Epoch 72/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6837 - g_loss: 0.7908
# Epoch 73/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6684 - g_loss: 0.8153
# Epoch 74/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6741 - g_loss: 0.7838
# Epoch 75/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6824 - g_loss: 0.7988
# Epoch 76/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6779 - g_loss: 0.8064
# Epoch 77/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6680 - g_loss: 0.8132
# Epoch 78/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6607 - g_loss: 0.8237
# Epoch 79/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6777 - g_loss: 0.7979
# Epoch 80/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6833 - g_loss: 0.7957
# Epoch 81/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6731 - g_loss: 0.7863
# Epoch 82/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6838 - g_loss: 0.8009
# Epoch 83/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6656 - g_loss: 0.8152
# Epoch 84/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6788 - g_loss: 0.7960
# Epoch 85/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6818 - g_loss: 0.8107
# Epoch 86/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6945 - g_loss: 0.7969
# Epoch 87/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6858 - g_loss: 0.8056
# Epoch 88/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6602 - g_loss: 0.8135
# Epoch 89/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6606 - g_loss: 0.8275
# Epoch 90/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6724 - g_loss: 0.8065
# Epoch 91/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6762 - g_loss: 0.8146
# Epoch 92/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6976 - g_loss: 0.7818
# Epoch 93/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6911 - g_loss: 0.7841
# Epoch 94/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7043 - g_loss: 0.7736
# Epoch 95/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6710 - g_loss: 0.8158
# Epoch 96/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7145 - g_loss: 0.7583
# Epoch 97/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7119 - g_loss: 0.8139
# Epoch 98/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6397 - g_loss: 0.8421
# Epoch 99/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6661 - g_loss: 0.8055
# Epoch 100/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6976 - g_loss: 0.7686
# Epoch 101/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6603 - g_loss: 0.8152
# Epoch 102/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6847 - g_loss: 0.8472
# Epoch 103/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6817 - g_loss: 0.7835
# Epoch 104/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7066 - g_loss: 0.7656
# Epoch 105/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6952 - g_loss: 0.7731
# Epoch 106/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6903 - g_loss: 0.7797
# Epoch 107/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6833 - g_loss: 0.7924
# Epoch 108/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6606 - g_loss: 0.8342
# Epoch 109/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6843 - g_loss: 0.7898
# Epoch 110/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6661 - g_loss: 0.8156
# Epoch 111/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6792 - g_loss: 0.8033
# Epoch 112/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6595 - g_loss: 0.8229
# Epoch 113/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6694 - g_loss: 0.8141
# Epoch 114/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7039 - g_loss: 0.8223
# Epoch 115/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6653 - g_loss: 0.8205
# Epoch 116/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6745 - g_loss: 0.8029
# Epoch 117/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6930 - g_loss: 0.7726
# Epoch 118/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6645 - g_loss: 0.8168
# Epoch 119/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6816 - g_loss: 0.8151
# Epoch 120/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6651 - g_loss: 0.8095
# Epoch 121/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6726 - g_loss: 0.8245
# Epoch 122/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6393 - g_loss: 0.9991
# Epoch 123/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7505 - g_loss: 0.7119
# Epoch 124/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6721 - g_loss: 0.7909
# Epoch 125/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6883 - g_loss: 0.7897
# Epoch 126/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6527 - g_loss: 0.8371
# Epoch 127/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6733 - g_loss: 0.8225
# Epoch 128/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6736 - g_loss: 0.8569
# Epoch 129/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6757 - g_loss: 0.8004
# Epoch 130/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6738 - g_loss: 0.8431
# Epoch 131/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6848 - g_loss: 0.8186
# Epoch 132/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6653 - g_loss: 0.8158
# Epoch 133/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6765 - g_loss: 0.8114
# Epoch 134/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6693 - g_loss: 0.8159
# Epoch 135/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6890 - g_loss: 0.7897
# Epoch 136/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6648 - g_loss: 0.8356
# Epoch 137/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6630 - g_loss: 0.8526
# Epoch 138/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6499 - g_loss: 0.8273
# Epoch 139/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6701 - g_loss: 0.8425
# Epoch 140/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6649 - g_loss: 0.8473
# Epoch 141/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6711 - g_loss: 0.8355
# Epoch 142/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6416 - g_loss: 0.8556
# Epoch 143/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6935 - g_loss: 0.9065
# Epoch 144/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6704 - g_loss: 0.8098
# Epoch 145/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6822 - g_loss: 0.7937
# Epoch 146/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6850 - g_loss: 0.7974
# Epoch 147/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6977 - g_loss: 0.7914
# Epoch 148/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6904 - g_loss: 0.7797
# Epoch 149/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6631 - g_loss: 0.8077
# Epoch 150/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6536 - g_loss: 0.8283
# Epoch 151/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6465 - g_loss: 0.8629
# Epoch 152/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6420 - g_loss: 0.8500
# Epoch 153/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6397 - g_loss: 0.8647
# Epoch 154/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6633 - g_loss: 0.8268
# Epoch 155/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7077 - g_loss: 0.7844
# Epoch 156/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6697 - g_loss: 0.8383
# Epoch 157/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6644 - g_loss: 0.8633
# Epoch 158/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6364 - g_loss: 0.8684
# Epoch 159/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6672 - g_loss: 0.8339
# Epoch 160/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6682 - g_loss: 0.8461
# Epoch 161/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6251 - g_loss: 0.8826
# Epoch 162/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6477 - g_loss: 0.8691
# Epoch 163/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6446 - g_loss: 0.9371
# Epoch 164/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6634 - g_loss: 0.8303
# Epoch 165/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6471 - g_loss: 0.8748
# Epoch 166/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6649 - g_loss: 0.8259
# Epoch 167/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6469 - g_loss: 0.8701
# Epoch 168/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6760 - g_loss: 0.8612
# Epoch 169/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6762 - g_loss: 0.8083
# Epoch 170/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6373 - g_loss: 0.8710
# Epoch 171/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4707 - g_loss: 2.0898
# Epoch 172/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7558 - g_loss: 0.7500
# Epoch 173/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6822 - g_loss: 0.8050
# Epoch 174/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6856 - g_loss: 0.8180
# Epoch 175/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6568 - g_loss: 0.8765
# Epoch 176/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6136 - g_loss: 0.9043
# Epoch 177/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6453 - g_loss: 0.8978
# Epoch 178/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6568 - g_loss: 0.8809
# Epoch 179/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6575 - g_loss: 0.8459
# Epoch 180/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6271 - g_loss: 0.9249
# Epoch 181/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7096 - g_loss: 0.8183
# Epoch 182/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6495 - g_loss: 0.8410
# Epoch 183/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6367 - g_loss: 0.9830
# Epoch 184/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6591 - g_loss: 0.8394
# Epoch 185/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6267 - g_loss: 0.9285
# Epoch 186/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6561 - g_loss: 0.8849
# Epoch 187/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6508 - g_loss: 0.8650
# Epoch 188/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6962 - g_loss: 0.8063
# Epoch 189/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6377 - g_loss: 0.9249
# Epoch 190/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7522 - g_loss: 0.8323
# Epoch 191/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6641 - g_loss: 0.8730
# Epoch 192/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6772 - g_loss: 0.8348
# Epoch 193/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6929 - g_loss: 0.8358
# Epoch 194/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7289 - g_loss: 0.7904
# Epoch 195/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6836 - g_loss: 0.8217
# Epoch 196/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6381 - g_loss: 0.8809
# Epoch 197/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6722 - g_loss: 0.8831
# Epoch 198/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6644 - g_loss: 0.8472
# Epoch 199/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7365 - g_loss: 0.7567
# Epoch 200/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6715 - g_loss: 0.8200
# Epoch 201/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6932 - g_loss: 0.8325
# Epoch 202/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7027 - g_loss: 0.7931
# Epoch 203/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6455 - g_loss: 0.8942
# Epoch 204/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6923 - g_loss: 0.8254
# Epoch 205/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6850 - g_loss: 0.8229
# Epoch 206/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6975 - g_loss: 0.8125
# Epoch 207/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6809 - g_loss: 0.8429
# Epoch 208/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6632 - g_loss: 0.9027
# Epoch 209/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6338 - g_loss: 0.8704
# Epoch 210/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6614 - g_loss: 0.8429
# Epoch 211/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6121 - g_loss: 0.9144
# Epoch 212/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6256 - g_loss: 0.9178
# Epoch 213/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6450 - g_loss: 0.8898
# Epoch 214/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6206 - g_loss: 0.9662
# Epoch 215/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6568 - g_loss: 0.8482
# Epoch 216/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6199 - g_loss: 0.9443
# Epoch 217/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6452 - g_loss: 0.8993
# Epoch 218/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7042 - g_loss: 0.8347
# Epoch 219/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6389 - g_loss: 0.9108
# Epoch 220/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7033 - g_loss: 0.8350
# Epoch 221/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6897 - g_loss: 0.8802
# Epoch 222/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6301 - g_loss: 0.8721
# Epoch 223/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6179 - g_loss: 0.9232
# Epoch 224/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6009 - g_loss: 0.9680
# Epoch 225/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5915 - g_loss: 0.9867
# Epoch 226/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4122 - g_loss: 2.1796
# Epoch 227/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7505 - g_loss: 0.8039
# Epoch 228/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6714 - g_loss: 0.8406
# Epoch 229/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6516 - g_loss: 0.8674
# Epoch 230/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5970 - g_loss: 1.0543
# Epoch 231/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6231 - g_loss: 0.8964
# Epoch 232/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6220 - g_loss: 0.8974
# Epoch 233/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6572 - g_loss: 0.8940
# Epoch 234/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6067 - g_loss: 0.9554
# Epoch 235/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6679 - g_loss: 0.8455
# Epoch 236/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6750 - g_loss: 0.8497
# Epoch 237/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6939 - g_loss: 0.9000
# Epoch 238/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5981 - g_loss: 0.9514
# Epoch 239/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6198 - g_loss: 0.9471
# Epoch 240/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6955 - g_loss: 0.8395
# Epoch 241/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6581 - g_loss: 0.8538
# Epoch 242/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6451 - g_loss: 0.9484
# Epoch 243/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6497 - g_loss: 0.9765
# Epoch 244/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5626 - g_loss: 0.9689
# Epoch 245/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6788 - g_loss: 0.8459
# Epoch 246/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7109 - g_loss: 0.9071
# Epoch 247/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6613 - g_loss: 0.8479
# Epoch 248/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6823 - g_loss: 0.8397
# Epoch 249/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6537 - g_loss: 0.8521
# Epoch 250/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6657 - g_loss: 0.8480
# Epoch 251/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6652 - g_loss: 0.9064
# Epoch 252/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5558 - g_loss: 1.0528
# Epoch 253/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6545 - g_loss: 0.9654
# Epoch 254/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6678 - g_loss: 0.8557
# Epoch 255/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6479 - g_loss: 0.8956
# Epoch 256/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6382 - g_loss: 0.8896
# Epoch 257/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6666 - g_loss: 0.9238
# Epoch 258/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7141 - g_loss: 0.8157
# Epoch 259/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6906 - g_loss: 0.8322
# Epoch 260/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7005 - g_loss: 0.8313
# Epoch 261/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6424 - g_loss: 0.9088
# Epoch 262/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5795 - g_loss: 0.9758
# Epoch 263/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6610 - g_loss: 0.8431
# Epoch 264/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6740 - g_loss: 1.0365
# Epoch 265/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6812 - g_loss: 0.8279
# Epoch 266/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6587 - g_loss: 1.2499
# Epoch 267/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6580 - g_loss: 0.8804
# Epoch 268/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6038 - g_loss: 0.9698
# Epoch 269/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6602 - g_loss: 0.8788
# Epoch 270/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6093 - g_loss: 0.9453
# Epoch 271/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5729 - g_loss: 1.0012
# Epoch 272/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6182 - g_loss: 1.0089
# Epoch 273/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6876 - g_loss: 0.8571
# Epoch 274/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6298 - g_loss: 0.8953
# Epoch 275/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6352 - g_loss: 0.9337
# Epoch 276/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6826 - g_loss: 0.9020
# Epoch 277/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6864 - g_loss: 0.8769
# Epoch 278/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5848 - g_loss: 1.0480
# Epoch 279/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6431 - g_loss: 0.9228
# Epoch 280/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6110 - g_loss: 0.9914
# Epoch 281/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6208 - g_loss: 0.9052
# Epoch 282/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5977 - g_loss: 0.9678
# Epoch 283/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6466 - g_loss: 0.9537
# Epoch 284/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6230 - g_loss: 0.9263
# Epoch 285/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6315 - g_loss: 1.0022
# Epoch 286/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7203 - g_loss: 0.8750
# Epoch 287/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7001 - g_loss: 0.8260
# Epoch 288/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6740 - g_loss: 0.8553
# Epoch 289/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7127 - g_loss: 0.8509
# Epoch 290/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6599 - g_loss: 0.8711
# Epoch 291/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6099 - g_loss: 0.9323
# Epoch 292/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6529 - g_loss: 0.8683
# Epoch 293/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6605 - g_loss: 0.9439
# Epoch 294/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6214 - g_loss: 0.9365
# Epoch 295/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6627 - g_loss: 0.8824
# Epoch 296/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6482 - g_loss: 0.9357
# Epoch 297/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6675 - g_loss: 0.9093
# Epoch 298/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6557 - g_loss: 0.8786
# Epoch 299/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6562 - g_loss: 0.9352
# Epoch 300/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6634 - g_loss: 0.8966
# Epoch 301/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6602 - g_loss: 0.9042
# Epoch 302/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6891 - g_loss: 0.8470
# Epoch 303/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6424 - g_loss: 0.9552
# Epoch 304/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6332 - g_loss: 0.9489
# Epoch 305/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6088 - g_loss: 0.9734
# Epoch 306/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6282 - g_loss: 0.9507
# Epoch 307/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6324 - g_loss: 0.9281
# Epoch 308/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6077 - g_loss: 0.9828
# Epoch 309/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6909 - g_loss: 0.8842
# Epoch 310/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6911 - g_loss: 0.9275
# Epoch 311/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6678 - g_loss: 0.9091
# Epoch 312/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6735 - g_loss: 0.8719
# Epoch 313/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5729 - g_loss: 1.1252
# Epoch 314/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7075 - g_loss: 0.9151
# Epoch 315/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6446 - g_loss: 0.8671
# Epoch 316/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7276 - g_loss: 0.8183
# Epoch 317/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6784 - g_loss: 0.8479
# Epoch 318/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6127 - g_loss: 0.9505
# Epoch 319/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6917 - g_loss: 0.8747
# Epoch 320/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6707 - g_loss: 0.8988
# Epoch 321/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6531 - g_loss: 0.8929
# Epoch 322/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5902 - g_loss: 1.0212
# Epoch 323/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5908 - g_loss: 0.9868
# Epoch 324/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6387 - g_loss: 0.9694
# Epoch 325/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7041 - g_loss: 0.8286
# Epoch 326/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6583 - g_loss: 0.9929
# Epoch 327/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6763 - g_loss: 0.8590
# Epoch 328/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5987 - g_loss: 0.9538
# Epoch 329/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6143 - g_loss: 0.9282
# Epoch 330/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6588 - g_loss: 0.9235
# Epoch 331/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6792 - g_loss: 0.8892
# Epoch 332/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6813 - g_loss: 0.8988
# Epoch 333/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6161 - g_loss: 0.9086
# Epoch 334/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6036 - g_loss: 0.9600
# Epoch 335/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6397 - g_loss: 0.9313
# Epoch 336/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6530 - g_loss: 1.0003
# Epoch 337/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6544 - g_loss: 0.9155
# Epoch 338/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6342 - g_loss: 0.9124
# Epoch 339/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6390 - g_loss: 0.9107
# Epoch 340/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6440 - g_loss: 0.9495
# Epoch 341/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6362 - g_loss: 0.9312
# Epoch 342/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6598 - g_loss: 1.0447
# Epoch 343/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6170 - g_loss: 0.9150
# Epoch 344/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6319 - g_loss: 0.9338
# Epoch 345/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6473 - g_loss: 0.9435
# Epoch 346/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5986 - g_loss: 0.9662
# Epoch 347/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5804 - g_loss: 1.0777
# Epoch 348/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6265 - g_loss: 0.9829
# Epoch 349/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6059 - g_loss: 0.9467
# Epoch 350/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6081 - g_loss: 1.0317
# Epoch 351/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6306 - g_loss: 0.9316
# Epoch 352/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5703 - g_loss: 1.0168
# Epoch 353/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6233 - g_loss: 0.9839
# Epoch 354/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6105 - g_loss: 0.9805
# Epoch 355/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6445 - g_loss: 0.9642
# Epoch 356/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6237 - g_loss: 0.9305
# Epoch 357/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6809 - g_loss: 0.9207
# Epoch 358/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6568 - g_loss: 0.8790
# Epoch 359/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6681 - g_loss: 0.8789
# Epoch 360/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6497 - g_loss: 0.9589
# Epoch 361/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6730 - g_loss: 0.8943
# Epoch 362/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5467 - g_loss: 1.0131
# Epoch 363/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6347 - g_loss: 0.9852
# Epoch 364/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5917 - g_loss: 0.9976
# Epoch 365/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6462 - g_loss: 1.0190
# Epoch 366/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5868 - g_loss: 1.0139
# Epoch 367/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5661 - g_loss: 1.0585
# Epoch 368/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6301 - g_loss: 0.9860
# Epoch 369/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6571 - g_loss: 0.9945
# Epoch 370/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5929 - g_loss: 0.9917
# Epoch 371/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5511 - g_loss: 1.3146
# Epoch 372/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6509 - g_loss: 0.9317
# Epoch 373/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5756 - g_loss: 1.0191
# Epoch 374/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6309 - g_loss: 0.9536
# Epoch 375/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.6046 - g_loss: 0.9984
# Epoch 376/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6752 - g_loss: 0.9461
# Epoch 377/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5720 - g_loss: 1.0149
# Epoch 378/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6117 - g_loss: 1.0399
# Epoch 379/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6355 - g_loss: 0.9489
# Epoch 380/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5436 - g_loss: 1.1155
# Epoch 381/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5554 - g_loss: 1.1034
# Epoch 382/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6271 - g_loss: 0.9971
# Epoch 383/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5251 - g_loss: 1.1065
# Epoch 384/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5706 - g_loss: 1.0455
# Epoch 385/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6954 - g_loss: 0.9410
# Epoch 386/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5589 - g_loss: 1.0781
# Epoch 387/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5325 - g_loss: 1.1294
# Epoch 388/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5790 - g_loss: 1.1649
# Epoch 389/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6164 - g_loss: 1.0052
# Epoch 390/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5669 - g_loss: 1.1717
# Epoch 391/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5575 - g_loss: 1.1220
# Epoch 392/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5340 - g_loss: 1.1201
# Epoch 393/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5412 - g_loss: 1.1792
# Epoch 394/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6106 - g_loss: 1.2549
# Epoch 395/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5360 - g_loss: 1.2429
# Epoch 396/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5987 - g_loss: 1.0600
# Epoch 397/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5473 - g_loss: 1.2914
# Epoch 398/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5541 - g_loss: 1.0767
# Epoch 399/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5097 - g_loss: 1.1957
# Epoch 400/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4935 - g_loss: 1.3216
# Epoch 401/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5296 - g_loss: 1.1502
# Epoch 402/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6224 - g_loss: 1.0778
# Epoch 403/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6158 - g_loss: 1.0189
# Epoch 404/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6394 - g_loss: 1.1674
# Epoch 405/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5770 - g_loss: 1.0455
# Epoch 406/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6053 - g_loss: 1.0284
# Epoch 407/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6107 - g_loss: 0.9833
# Epoch 408/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6430 - g_loss: 1.0210
# Epoch 409/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5735 - g_loss: 1.0382
# Epoch 410/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5393 - g_loss: 1.1509
# Epoch 411/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5226 - g_loss: 3.3474
# Epoch 412/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5077 - g_loss: 1.0963
# Epoch 413/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5531 - g_loss: 1.1311
# Epoch 414/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6346 - g_loss: 1.0104
# Epoch 415/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4789 - g_loss: 1.1678
# Epoch 416/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5633 - g_loss: 1.1954
# Epoch 417/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4885 - g_loss: 1.2235
# Epoch 418/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6282 - g_loss: 1.3795
# Epoch 419/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7630 - g_loss: 0.8265
# Epoch 420/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5711 - g_loss: 1.0467
# Epoch 421/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5549 - g_loss: 1.0847
# Epoch 422/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5653 - g_loss: 1.1401
# Epoch 423/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5552 - g_loss: 1.1119
# Epoch 424/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5986 - g_loss: 1.0733
# Epoch 425/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5442 - g_loss: 1.1356
# Epoch 426/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5815 - g_loss: 1.3483
# Epoch 427/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5719 - g_loss: 1.2093
# Epoch 428/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6474 - g_loss: 1.0090
# Epoch 429/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4923 - g_loss: 1.3168
# Epoch 430/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5529 - g_loss: 1.1641
# Epoch 431/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5518 - g_loss: 1.1599
# Epoch 432/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6231 - g_loss: 1.0672
# Epoch 433/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5393 - g_loss: 1.1747
# Epoch 434/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6053 - g_loss: 1.1416
# Epoch 435/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5391 - g_loss: 1.2643
# Epoch 436/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5634 - g_loss: 1.1898
# Epoch 437/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5040 - g_loss: 1.1369
# Epoch 438/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5254 - g_loss: 1.2150
# Epoch 439/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5280 - g_loss: 1.1618
# Epoch 440/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5044 - g_loss: 1.3002
# Epoch 441/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4976 - g_loss: 1.2834
# Epoch 442/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5489 - g_loss: 1.1347
# Epoch 443/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4903 - g_loss: 1.2608
# Epoch 444/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5171 - g_loss: 1.2993
# Epoch 445/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5638 - g_loss: 1.2093
# Epoch 446/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5473 - g_loss: 1.1696
# Epoch 447/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5451 - g_loss: 2.4564
# Epoch 448/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6068 - g_loss: 1.1541
# Epoch 449/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.7183 - g_loss: 0.8658
# Epoch 450/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5738 - g_loss: 0.9743
# Epoch 451/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6399 - g_loss: 1.0332
# Epoch 452/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5671 - g_loss: 1.0560
# Epoch 453/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5098 - g_loss: 1.1748
# Epoch 454/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5681 - g_loss: 1.1785
# Epoch 455/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6084 - g_loss: 1.0980
# Epoch 456/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5444 - g_loss: 1.1311
# Epoch 457/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5099 - g_loss: 1.1870
# Epoch 458/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6058 - g_loss: 1.0714
# Epoch 459/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5262 - g_loss: 1.1910
# Epoch 460/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5853 - g_loss: 1.1309
# Epoch 461/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5261 - g_loss: 1.1568
# Epoch 462/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6348 - g_loss: 1.0870
# Epoch 463/2500
# ...
# Epoch 1261/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4262 - g_loss: 1.6170
# Epoch 1262/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.3990 - g_loss: 1.6209
# Epoch 1263/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4961 - g_loss: 1.5093
# Epoch 1264/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4122 - g_loss: 1.8149
# Epoch 1265/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4358 - g_loss: 1.4431
# Epoch 1266/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4290 - g_loss: 1.4746
# Epoch 1267/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4792 - g_loss: 1.5788
# Epoch 1268/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4555 - g_loss: 1.4544
# Epoch 1269/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5056 - g_loss: 2.2513
# Epoch 1270/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4358 - g_loss: 1.4030
# Epoch 1271/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5324 - g_loss: 1.3221
# Epoch 1272/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5651 - g_loss: 1.4138
# Epoch 1273/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4483 - g_loss: 1.5653
# Epoch 1274/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4863 - g_loss: 1.5289
# Epoch 1275/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6028 - g_loss: 1.1846
# Epoch 1276/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4491 - g_loss: 1.3710
# Epoch 1277/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4011 - g_loss: 1.5358
# Epoch 1278/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4474 - g_loss: 1.4033
# Epoch 1279/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4952 - g_loss: 1.4779
# Epoch 1280/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3903 - g_loss: 1.7180
# Epoch 1281/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4709 - g_loss: 1.3731
# Epoch 1282/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4781 - g_loss: 1.4582
# Epoch 1283/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3473 - g_loss: 1.7445
# Epoch 1284/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4382 - g_loss: 1.7476
# Epoch 1285/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3942 - g_loss: 1.5537
# Epoch 1286/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4433 - g_loss: 1.5412
# Epoch 1287/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5906 - g_loss: 1.6894
# Epoch 1288/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4159 - g_loss: 1.4112
# Epoch 1289/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3277 - g_loss: 1.6877
# Epoch 1290/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4464 - g_loss: 1.6224
# Epoch 1291/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3717 - g_loss: 1.9581
# Epoch 1292/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4084 - g_loss: 1.6101
# Epoch 1293/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3199 - g_loss: 1.7685
# Epoch 1294/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4705 - g_loss: 1.5799
# Epoch 1295/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3690 - g_loss: 1.6195
# Epoch 1296/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3312 - g_loss: 1.7726
# Epoch 1297/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3913 - g_loss: 1.7328
# Epoch 1298/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3833 - g_loss: 1.6476
# Epoch 1299/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4012 - g_loss: 2.0428
# Epoch 1300/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5909 - g_loss: 1.5256
# Epoch 1301/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4641 - g_loss: 1.4890
# Epoch 1302/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3654 - g_loss: 1.6067
# Epoch 1303/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3616 - g_loss: 1.6466
# Epoch 1304/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4590 - g_loss: 1.5285
# Epoch 1305/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3948 - g_loss: 1.6018
# Epoch 1306/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4431 - g_loss: 1.7555
# Epoch 1307/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4459 - g_loss: 1.5416
# Epoch 1308/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4837 - g_loss: 1.5516
# Epoch 1309/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3834 - g_loss: 1.5985
# Epoch 1310/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3818 - g_loss: 1.6785
# Epoch 1311/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3329 - g_loss: 1.8291
# Epoch 1312/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5671 - g_loss: 1.4469
# Epoch 1313/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4225 - g_loss: 1.4200
# Epoch 1314/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.4037 - g_loss: 1.6071
# Epoch 1315/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5476 - g_loss: 1.8101
# Epoch 1316/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4928 - g_loss: 1.4831
# Epoch 1317/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.2361 - g_loss: 3.0122
# Epoch 1318/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.6121 - g_loss: 1.4898
# Epoch 1319/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4876 - g_loss: 1.2785
# Epoch 1320/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3972 - g_loss: 1.4312
# Epoch 1321/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3865 - g_loss: 1.6250
# Epoch 1322/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4286 - g_loss: 1.5888
# Epoch 1323/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3676 - g_loss: 1.7078
# Epoch 1324/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3428 - g_loss: 1.6869
# Epoch 1325/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4348 - g_loss: 1.5731
# Epoch 1326/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3828 - g_loss: 1.6819
# Epoch 1327/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.3641 - g_loss: 2.1339
# Epoch 1328/2500
# 197/197 [==============================] - 2s 9ms/step - d_loss: 0.5279 - g_loss: 1.3344
# Epoch 1329/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5603 - g_loss: 1.4771
# Epoch 1330/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4378 - g_loss: 1.4023
# Epoch 1331/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4365 - g_loss: 1.4459
# Epoch 1332/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.5391 - g_loss: 1.4592
# Epoch 1333/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4766 - g_loss: 1.4612
# Epoch 1334/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4284 - g_loss: 1.6402
# Epoch 1335/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4169 - g_loss: 1.5251
# Epoch 1336/2500
# 197/197 [==============================] - 2s 8ms/step - d_loss: 0.4209 - g_loss: 1.4166
# Epoch 1337/2500
# 155/197 [======================>.......] - ETA: 0s - d_loss: 0.4271 - g_loss: 1.5621
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\telab\OneDrive - 独立行政法人 国立高等専門学校機構\Lepa\GANs\Paper_GAN_2D.ipynb Cell 14 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Paper_GAN_2D.ipynb#ch0000013?line=2'>3</a> gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Paper_GAN_2D.ipynb#ch0000013?line=3'>4</a> gan.compile(
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Paper_GAN_2D.ipynb#ch0000013?line=4'>5</a>     d_optimizer=keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.2),
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Paper_GAN_2D.ipynb#ch0000013?line=5'>6</a>     g_optimizer=keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.2),
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Paper_GAN_2D.ipynb#ch0000013?line=6'>7</a>     loss_fn=keras.losses.BinaryCrossentropy(from_logits=False),
#       <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Paper_GAN_2D.ipynb#ch0000013?line=7'>8</a> )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Paper_GAN_2D.ipynb#ch0000013?line=9'>10</a> gan.fit(
#      <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Paper_GAN_2D.ipynb#ch0000013?line=10'>11</a>     train_dataset, epochs=epochs, callbacks=[GANMonitor(num_img=1, latent_dim=latent_dim), model_checkpoint_callback]
#      <a href='vscode-notebook-cell:/c%3A/Users/telab/OneDrive%20-%20%E7%8B%AC%E7%AB%8B%E8%A1%8C%E6%94%BF%E6%B3%95%E4%BA%BA%20%E5%9B%BD%E7%AB%8B%E9%AB%98%E7%AD%89%E5%B0%82%E9%96%80%E5%AD%A6%E6%A0%A1%E6%A9%9F%E6%A7%8B/Lepa/GANs/Paper_GAN_2D.ipynb#ch0000013?line=11'>12</a> )
#
# File c:\Users\telab\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\telab\anaconda3\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Users\telab\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
